# %%
# %matplotlib notebook
import os
import pandas as pd
import numpy as np

# %%
# File to Load (Remember to Change These)
file_to_load = "../../Resources/casos-asociados-a-covid-19.csv"

# Read Purchasing File and store into Pandas data frame
covid_cases_data = pd.read_csv(file_to_load)
covid_cases_data.head()
# Out:
#   FECHA ACTUALIZACION ID_REGISTRO ORIGEN SECTOR  \
# 0          2020-06-24      076847  USMER    SSA
# 1          2020-06-24      0f2b37  USMER    SSA
# 2          2020-06-24      1aa59e  USMER    SSA
# 3          2020-06-24      190217  USMER    SSA
# 4          2020-06-24      169761  USMER    SSA
#
#              ENTIDAD UNIDAD MEDICA    SEXO               ENTIDAD NACIMIENTO  \
# 0                           PUEBLA   MUJER                           PUEBLA
# 1                          CHIAPAS  HOMBRE                          CHIAPAS
# 2  VERACRUZ DE IGNACIO DE LA LLAVE   MUJER  VERACRUZ DE IGNACIO DE LA LLAVE
# 3                           SONORA   MUJER                           SONORA
# 4                          YUCATÁN  HOMBRE                          YUCATÁN
#
#                 ENTIDAD RESIDENCIA MUNICIPIO RESIDENCIA  TIPO PACIENTE  ...  \
# 0                           PUEBLA                  NaN    AMBULATORIO  ...
# ...

# %%
clean_covid_data = covid_cases_data[["ID_REGISTRO","SEXO","MUNICIPIO RESIDENCIA","FECHA INGRESO", "FECHA DEFUNCION","INTUBADO","EDAD","DIABETES","EPOC","ASMA","INMUNOSUPRESION","HIPERTENSION","CARDIOVASCULAR","OBESIDAD","RENAL CRONICA","TABAQUISMO"]]
display(clean_covid_data)
# Out:
#        ID_REGISTRO    SEXO MUNICIPIO RESIDENCIA FECHA INGRESO FECHA DEFUNCION  \
# 0           076847   MUJER                  NaN    2020-06-01             NaN
# 1           0f2b37  HOMBRE                  NaN    2020-06-02             NaN
# 2           1aa59e   MUJER                  NaN    2020-06-15             NaN
# 3           190217   MUJER                  NaN    2020-06-13             NaN
# 4           169761  HOMBRE                  NaN    2020-06-16             NaN
# ...            ...     ...                  ...           ...             ...
# 515653      1b2821   MUJER       Álvaro Obregón    2020-04-24             NaN
# 515654      1c1174   MUJER                  NaN    2020-06-09             NaN
# 515655      1a1c43   MUJER       Miguel Hidalgo    2020-06-10             NaN
# 515656      062e79   MUJER                  NaN    2020-06-10             NaN
# 515657      123e91   MUJER           Xochimilco    2020-06-06             NaN
#
# ...

# %%
casos_municipio = clean_covid_data.groupby(["MUNICIPIO RESIDENCIA"]).count().rename(columns={'ID_REGISTRO':'CASOS'}).drop(['SEXO','FECHA INGRESO','FECHA DEFUNCION','INTUBADO','EDAD','DIABETES','EPOC','ASMA','INMUNOSUPRESION','HIPERTENSION','CARDIOVASCULAR','OBESIDAD','RENAL CRONICA','TABAQUISMO'],axis=1).reset_index()
casos_municipio
# Out:
#       MUNICIPIO RESIDENCIA  CASOS
# 0             Azcapotzalco  19915
# 1            Benito Juárez  10128
# 2                 Coyoacán  13095
# 3    Cuajimalpa de Morelos  19582
# 4               Cuauhtémoc   8808
# 5        Gustavo A. Madero  22121
# 6                Iztacalco  16876
# 7               Iztapalapa  25560
# 8   La Magdalena Contreras   7259
# 9           Miguel Hidalgo   6099
# 10              Milpa Alta   7235
# 11                 Tlalpan  14021
# 12                 Tláhuac   9424
# 13     Venustiano Carranza  13568
# 14              Xochimilco  13047
# 15          Álvaro Obregón  10808
