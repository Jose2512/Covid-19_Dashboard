# %%
# %matplotlib notebook
import os
import pandas as pd
import numpy as np
import pymongo

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")

#DATABASE
covid = myclient.Covid_DB

# %%
file_to_load = "../../Resources/casos-asociados-a-covid-19.csv"

covid_cases_data = pd.read_csv(file_to_load)
covid_cases_data.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (30,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   FECHA ACTUALIZACION ID_REGISTRO ORIGEN SECTOR  \
# 0          2020-06-24      076847  USMER    SSA
# 1          2020-06-24      0f2b37  USMER    SSA
# 2          2020-06-24      1aa59e  USMER    SSA
# 3          2020-06-24      190217  USMER    SSA
# 4          2020-06-24      169761  USMER    SSA
#
#              ENTIDAD UNIDAD MEDICA    SEXO               ENTIDAD NACIMIENTO  \
# 0                           PUEBLA   MUJER                           PUEBLA
# 1                          CHIAPAS  HOMBRE                          CHIAPAS
# 2  VERACRUZ DE IGNACIO DE LA LLAVE   MUJER  VERACRUZ DE IGNACIO DE LA LLAVE
# 3                           SONORA   MUJER                           SONORA
# 4                          YUCATÁN  HOMBRE                          YUCATÁN
#
#                 ENTIDAD RESIDENCIA MUNICIPIO RESIDENCIA  TIPO PACIENTE  ...  \
# 0                           PUEBLA                  NaN    AMBULATORIO  ...
# 1                          CHIAPAS                  NaN    AMBULATORIO  ...
# 2  VERACRUZ DE IGNACIO DE LA LLAVE                  NaN    AMBULATORIO  ...
# 3                           SONORA                  NaN  HOSPITALIZADO  ...
# 4                          YUCATÁN                  NaN    AMBULATORIO  ...
#
#   Negativo         MIGRANTE PAIS NACIONALIDAD PAIS ORIGEN  \
# 0      NaN  NO ESPECIFICADO            México          99
# 1      NaN  NO ESPECIFICADO            México          99
# 2      NaN  NO ESPECIFICADO            México          99
# 3      NaN  NO ESPECIFICADO            México          99
# 4      NaN  NO ESPECIFICADO            México          99
#
#   UNIDAD DE CUIDADOS INTENSIVOS  RANGO EDAD num_fallecidos num_hospitalizados  \
# 0                     NO APLICA       31-40            NaN                NaN
# 1                     NO APLICA       31-40            NaN                NaN
# 2                     NO APLICA       41-50            NaN                NaN
# 3                            NO       41-50            NaN                1.0
# 4                     NO APLICA       31-40            NaN                NaN
#
#               positivo pendiente
# 0  Positivo SARS-CoV-2       NaN
# 1  Positivo SARS-CoV-2       NaN
# 2  Positivo SARS-CoV-2       NaN
# 3  Positivo SARS-CoV-2       NaN
# 4  Positivo SARS-CoV-2       NaN
#
# [5 rows x 40 columns]

# %%
file_to_load = "../../Resources/capacidad-hospitalaria.csv"

capacidad_hospitalaria = pd.read_csv(file_to_load)
capacidad_hospitalaria.tail()
# Out:
#            Fecha                                    Nombre_hospital  \
# 5453  2020-06-25       HOSPITAL GENERAL DE IXTAPALUCA "PEDRO LOPEZ"
# 5454  2020-06-25                         HOSPITAL GENERAL DE CHALCO
# 5455  2020-06-25  HOSPITAL GENERAL TEXCOCO "GUADALUPE VICTORIA" ...
# 5456  2020-06-25  HOSPITAL GENERAL AMECAMECA "VALENTIN GOMEZ FAR...
# 5457  2020-06-25                       HOSPITAL GENERAL DE AXAPUSCO
#
#      Institucion Estatus_capacidad_hospitalaria Estatus_capacidad_UCI  \
# 5453      EDOMEX                          Buena                 Buena
# 5454      EDOMEX                          Buena                 Media
# 5455      EDOMEX                          Buena                 Media
# 5456      EDOMEX                          Buena                 Buena
# 5457      EDOMEX                          Media               Crítica
#
#                Coordenadas
# 5453  19.318829,-98.855366
# 5454  19.268265,-98.893965
# 5455   19.514309,-98.87175
# 5456  19.144883,-98.785072
# 5457  19.732872,-98.769445

# %%
file_to_load = "../../Resources/afluencia-preliminar-en-transporte-publico.csv"

daily_transport_data = pd.read_csv(file_to_load)
daily_transport_data.head()
# Out:
#         FECHA  DÍA MES DÍA SEMANA      MES   AÑO ORGANISMO LINEA/SERVICIO  \
# 0  2020-03-09        9      Lunes  2020-03  2020   Ecobici            NaN
# 1  2020-03-11       11  Miércoles  2020-03  2020   Ecobici            NaN
# 2  2020-03-13       13    Viernes  2020-03  2020   Ecobici            NaN
# 3  2020-03-15       15    Domingo  2020-03  2020   Ecobici            NaN
# 4  2020-03-24       24     Martes  2020-03  2020   Ecobici            NaN
#
#    AFLUENCIA TARJETA  AFLUENCIA BOLETO  AFLUENCIA TOTAL\n(cifras preliminares)
# 0                NaN               NaN                                 23154.0
# 1                NaN               NaN                                 31609.0
# 2                NaN               NaN                                 28080.0
# 3                NaN               NaN                                  8492.0
# 4                NaN               NaN                                 11358.0

# %%
clean_covid_data = covid_cases_data[covid_cases_data["Negativo"]!="No positivo SARS-CoV-2"]
clean_covid_data = clean_covid_data[["ID_REGISTRO","SEXO","MUNICIPIO RESIDENCIA","FECHA INGRESO", "FECHA DEFUNCION","INTUBADO","EDAD","DIABETES","EPOC","ASMA","INMUNOSUPRESION","HIPERTENSION","CARDIOVASCULAR","OBESIDAD","RENAL CRONICA","TABAQUISMO"]]
clean_covid_data = clean_covid_data.fillna("NO")
display(clean_covid_data)
# Out:
#        ID_REGISTRO    SEXO MUNICIPIO RESIDENCIA FECHA INGRESO FECHA DEFUNCION  \
# 0           076847   MUJER                   NO    2020-06-01              NO
# 1           0f2b37  HOMBRE                   NO    2020-06-02              NO
# 2           1aa59e   MUJER                   NO    2020-06-15              NO
# 3           190217   MUJER                   NO    2020-06-13              NO
# 4           169761  HOMBRE                   NO    2020-06-16              NO
# ...            ...     ...                  ...           ...             ...
# 490621      0db5d1   MUJER                   NO    2020-05-28              NO
# 490622      1dc64a  HOMBRE                   NO    2020-05-27              NO
# 490623      130185   MUJER           Iztapalapa    2020-05-12              NO
# 490624      186960   MUJER            Iztacalco    2020-04-15              NO
# 490625      07be2e  HOMBRE                   NO    2020-05-23      2020-05-24
#
#          INTUBADO  EDAD DIABETES EPOC ASMA INMUNOSUPRESION HIPERTENSION  \
# 0       NO APLICA    36       NO   NO   NO              NO           NO
# 1       NO APLICA    32       NO   NO   NO              NO           NO
# 2       NO APLICA    43       NO   NO   NO              NO           NO
# 3              NO    42       NO   NO   NO              NO           SI
# 4       NO APLICA    33       NO   NO   NO              NO           NO
# ...           ...   ...      ...  ...  ...             ...          ...
# 490621  NO APLICA    60       SI   NO   NO              NO           NO
# 490622  NO APLICA    32       NO   NO   NO              NO           NO
# 490623  NO APLICA    52       NO   NO   NO              NO           NO
# 490624  NO APLICA    47       NO   NO   NO              NO           NO
# 490625  NO APLICA    57       NO   NO   NO              NO           SI
#
#        CARDIOVASCULAR OBESIDAD RENAL CRONICA TABAQUISMO
# 0                  NO       NO            NO         NO
# 1                  NO       NO            NO         NO
# 2                  NO       NO            NO         NO
# 3                  NO       NO            NO         NO
# 4                  NO       NO            NO         NO
# ...               ...      ...           ...        ...
# 490621             NO       NO            NO         NO
# 490622             NO       SI            NO         NO
# 490623             NO       NO            NO         NO
# 490624             NO       SI            NO         NO
# 490625             NO       SI            NO         NO
#
# [259322 rows x 16 columns]

# %%
capacidad_hospitalaria_limpia = capacidad_hospitalaria[capacidad_hospitalaria["Fecha"]==capacidad_hospitalaria["Fecha"].iloc[-1]].reset_index().drop(columns=["index"])
capacidad_hospitalaria_limpia = capacidad_hospitalaria_limpia[capacidad_hospitalaria_limpia["Estatus_capacidad_hospitalaria"]!="Sin dato"]
coordenadas = capacidad_hospitalaria_limpia["Coordenadas"].str.split(",", n = 1, expand = True) 
capacidad_hospitalaria_limpia["Lat"]= coordenadas[0] 
capacidad_hospitalaria_limpia["Lon"]= coordenadas[1] 
capacidad_hospitalaria_limpia.drop(columns =["Coordenadas"], inplace = True) 
capacidad_hospitalaria_limpia
# Out:
#          Fecha                                    Nombre_hospital Institucion  \
# 0   2020-06-25                    INSTITUTO NACIONAL DE NUTRICIÓN         SSA
# 1   2020-06-25                         HOSPITAL GENERAL DE MÉXICO         SSA
# 2   2020-06-25           HOSPITAL GENERAL DR. MANUEL GEA GONZÁLEZ         SSA
# 3   2020-06-25                                        CITIBANAMEX         SSA
# 4   2020-06-25  HOSPITAL REGIONAL DE ALTA ESPECIALIDAD DE IXTA...         SSA
# ..         ...                                                ...         ...
# 71  2020-06-25       HOSPITAL GENERAL DE IXTAPALUCA "PEDRO LOPEZ"      EDOMEX
# 72  2020-06-25                         HOSPITAL GENERAL DE CHALCO      EDOMEX
# 73  2020-06-25  HOSPITAL GENERAL TEXCOCO "GUADALUPE VICTORIA" ...      EDOMEX
# 74  2020-06-25  HOSPITAL GENERAL AMECAMECA "VALENTIN GOMEZ FAR...      EDOMEX
# 75  2020-06-25                       HOSPITAL GENERAL DE AXAPUSCO      EDOMEX
#
#    Estatus_capacidad_hospitalaria Estatus_capacidad_UCI         Lat  \
# 0                         Crítica               Crítica   19.289599
# 1                           Media                 Media  19.4129258
# 2                         Crítica                 Media   19.290295
# 3                           Media               Crítica   19.439732
# 4                           Media                 Media   19.318796
# ..                            ...                   ...         ...
# 71                          Buena                 Buena   19.318829
# 72                          Buena                 Media   19.268265
# 73                          Buena                 Media   19.514309
# 74                          Buena                 Buena   19.144883
# 75                          Media               Crítica   19.732872
#
#             Lon
# 0    -99.155441
# 1   -99.1520225
# 2    -99.160861
# 3    -99.224235
# 4    -98.855353
# ..          ...
# 71   -98.855366
# 72   -98.893965
# 73    -98.87175
# 74   -98.785072
# 75   -98.769445
#
# [75 rows x 7 columns]

# %%
pd.DataFrame.to_csv(capacidad_hospitalaria_limpia,'../assets/data/capacidad_hospitalaria.csv',encoding='latin1')
capacidad_hospitalaria_limpia.to_json('../assets/data/capacidad_hospitalaria.json',orient='records')

# %%
#COLLECTION
capacidad_hospitalaria=covid.capacidad_hospitalaria

data_dict = capacidad_hospitalaria_limpia.to_dict("records")

for record in data_dict:
    capacidad_hospitalaria.insert_one(record)
    
data_dict
# Out:
# [{'Fecha': '2020-06-25',
#   'Nombre_hospital': 'INSTITUTO NACIONAL DE NUTRICIÓN',
#   'Institucion': 'SSA',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Crítica',
#   'Lat': '19.289599',
#   'Lon': '-99.155441',
#   '_id': ObjectId('5efacbe00479130f19c03858')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE MÉXICO',
#   'Institucion': 'SSA',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.4129258',
#   'Lon': '-99.1520225',
#   '_id': ObjectId('5efacbe00479130f19c03859')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DR. MANUEL GEA GONZÁLEZ',
#   'Institucion': 'SSA',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.290295',
#   'Lon': '-99.160861',
#   '_id': ObjectId('5efacbe00479130f19c0385a')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'CITIBANAMEX',
#   'Institucion': 'SSA',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Crítica',
#   'Lat': '19.439732',
#   'Lon': '-99.224235',
#   '_id': ObjectId('5efacbe00479130f19c0385b')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL REGIONAL DE ALTA ESPECIALIDAD DE IXTAPALUCA',
#   'Institucion': 'SSA',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.318796',
#   'Lon': '-98.855353',
#   '_id': ObjectId('5efacbe00479130f19c0385c')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'GENERAL TLAHUAC',
#   'Institucion': 'SEDESA',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.287492',
#   'Lon': '-99.052665',
#   '_id': ObjectId('5efacbe00479130f19c0385d')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL AJUSCO MEDIO',
#   'Institucion': 'SEDESA',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.272165',
#   'Lon': '-99.207846',
#   '_id': ObjectId('5efacbe00479130f19c0385e')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL IZTAPALAPA',
#   'Institucion': 'SEDESA',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.343426',
#   'Lon': '-99.027236',
#   '_id': ObjectId('5efacbe00479130f19c0385f')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DR. RUBÉN LEÑERO',
#   'Institucion': 'SEDESA',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.451398',
#   'Lon': '-99.169565',
#   '_id': ObjectId('5efacbe00479130f19c03860')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL DE ESPECIALIDADES 01 CMN SIGLO XXI (CDMX SUR)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.466549',
#   'Lon': '-99.145102',
#   '_id': ObjectId('5efacbe00479130f19c03861')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL DE PEDIATRIA 01 CMN SIGLO XXI (CDMX SUR)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.407458',
#   'Lon': '-99.152267',
#   '_id': ObjectId('5efacbe00479130f19c03862')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 1A PARQUE DE LOS VENADOS (CDMX SUR)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.374431',
#   'Lon': '-99.151203',
#   '_id': ObjectId('5efacbe00479130f19c03863')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL 01 (CDMX NORTE) LA RAZA',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.39574',
#   'Lon': '-99.161677',
#   '_id': ObjectId('5efacbe00479130f19c03864')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 30 (CDMX SUR)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.398836',
#   'Lon': '-99.116913',
#   '_id': ObjectId('5efacbe00479130f19c03865')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 32 (CDMX SUR)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.307964',
#   'Lon': '-99.130677',
#   '_id': ObjectId('5efacbe00479130f19c03866')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL REGIONAL 72',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.542797',
#   'Lon': '-99.205022',
#   '_id': ObjectId('5efacbe00479130f19c03867')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL REGIONAL 196',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.529016',
#   'Lon': '-99.030983',
#   '_id': ObjectId('5efacbe00479130f19c03868')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 57 (LA QUEBRADA)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Crítica',
#   'Lat': '19.597387',
#   'Lon': '-99.188426',
#   '_id': ObjectId('5efacbe00479130f19c03869')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'CENTRO MEDICO 20 DE NOVIEMBRE',
#   'Institucion': 'ISSSTE',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.37272',
#   'Lon': '-99.171205',
#   '_id': ObjectId('5efacbe00479130f19c0386a')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HG DR FERNANDO QUIROZ',
#   'Institucion': 'ISSSTE',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.394242',
#   'Lon': '-99.194187',
#   '_id': ObjectId('5efacbe00479130f19c0386b')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HR LIC. ADOLFO LÓPEZ MATEOS',
#   'Institucion': 'ISSSTE',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.358451',
#   'Lon': '-99.172716',
#   '_id': ObjectId('5efacbe00479130f19c0386c')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HR BICENTENARIO DE LA INDEPENDENCIA',
#   'Institucion': 'ISSSTE',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.628814',
#   'Lon': '-99.163343',
#   '_id': ObjectId('5efacbe00479130f19c0386d')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'ALTA ESPECIALIDAD DE ZUMPANGO',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.815198',
#   'Lon': '-99.089196',
#   '_id': ObjectId('5efacbe00479130f19c0386e')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL REGIONAL TLALNEPANTLA ISSEMYM',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.521706',
#   'Lon': '-99.187341',
#   '_id': ObjectId('5efacbe00479130f19c0386f')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL CUAUTITLAN "GRAL. JOSE VICENTE VILLADA"',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.664586',
#   'Lon': '-99.178557',
#   '_id': ObjectId('5efacbe00479130f19c03870')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL JUAREZ',
#   'Institucion': 'SSA',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.481829',
#   'Lon': '-99.135576',
#   '_id': ObjectId('5efacbe00479130f19c03871')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'BELISARIO DOMINGUEZ',
#   'Institucion': 'SEDESA',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.307226',
#   'Lon': '-99.065356',
#   '_id': ObjectId('5efacbe00479130f19c03872')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'ENRIQUE CABRERA',
#   'Institucion': 'SEDESA',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.361675',
#   'Lon': '-99.224432',
#   '_id': ObjectId('5efacbe00479130f19c03873')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL XOCO',
#   'Institucion': 'SEDESA',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.360313',
#   'Lon': '-99.162275',
#   '_id': ObjectId('5efacbe00479130f19c03874')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL BALBUENA',
#   'Institucion': 'SEDESA',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.424195',
#   'Lon': '-99.115412',
#   '_id': ObjectId('5efacbe00479130f19c03875')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL DE INFECTOLOGIA 01 LA RAZA (CDMX NORTE)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.464865',
#   'Lon': '-99.144859',
#   '_id': ObjectId('5efacbe00479130f19c03876')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 2A (CDMX SUR)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.405495',
#   'Lon': '-99.1122',
#   '_id': ObjectId('5efacbe00479130f19c03877')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA C/UMAA 48 (CDMX NORTE)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.482375',
#   'Lon': '-99.213046',
#   '_id': ObjectId('5efacbe00479130f19c03878')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL DE ESPECIALIDADES 01 (CDMX NORTE) LA RAZA (AZC)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.467169',
#   'Lon': '-99.143785',
#   '_id': ObjectId('5efacbe00479130f19c03879')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 47 (CDMX SUR) (IZP)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.357566',
#   'Lon': '-99.054269',
#   '_id': ObjectId('5efacbe00479130f19c0387a')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'UNIDAD MÓVIL TEMPORAL COVID',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.403082',
#   'Lon': '-99.089177',
#   '_id': ObjectId('5efacbe00479130f19c0387b')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 53',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.356913',
#   'Lon': '-98.990929',
#   '_id': ObjectId('5efacbe00479130f19c0387c')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 68 (TULPETLAC)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.57007',
#   'Lon': '-99.044009',
#   '_id': ObjectId('5efacbe00479130f19c0387d')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HG JOSE MARIA MORELOS',
#   'Institucion': 'ISSSTE',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.363918',
#   'Lon': '-98.995393',
#   '_id': ObjectId('5efacbe00479130f19c0387e')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HG TACUBA',
#   'Institucion': 'ISSSTE',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.454384',
#   'Lon': '-99.191231',
#   '_id': ObjectId('5efacbe00479130f19c0387f')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HG IGNACIO ZARAGOZA',
#   'Institucion': 'ISSSTE',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.389472',
#   'Lon': '-99.045019',
#   '_id': ObjectId('5efacbe00479130f19c03880')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HR PRIMERO DE OCTUBRE',
#   'Institucion': 'ISSSTE',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.486751',
#   'Lon': '-99.133249',
#   '_id': ObjectId('5efacbe00479130f19c03881')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL ECATEPEC "LAS AMÉRICAS"',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.594136',
#   'Lon': '-99.018679',
#   '_id': ObjectId('5efacbe00479130f19c03882')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE NAUCALPAN "DR. MAXIMILIANO RUIZ CASTAÑEDA"',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.468662',
#   'Lon': '-99.234348',
#   '_id': ObjectId('5efacbe00479130f19c03883')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL ATIZAPAN DE ZARAGOZA "DR. SALVADOR GONZALEZ HERREJÓN"',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.546322',
#   'Lon': '-99.237491',
#   '_id': ObjectId('5efacbe00479130f19c03884')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE CHIMALHUACAN',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.419753',
#   'Lon': '-98.97514',
#   '_id': ObjectId('5efacbe00479130f19c03885')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL VALLE DE CHALCO "DR. FERNANDO QUIROZ GUTIERREZ"',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.273775',
#   'Lon': '-98.941609',
#   '_id': ObjectId('5efacbe00479130f19c03886')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'INER',
#   'Institucion': 'SSA',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.291375',
#   'Lon': '-99.158653',
#   '_id': ObjectId('5efacbe00479130f19c03887')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL INFANTIL DE MÉXICO FEDERICO GÓMEZ',
#   'Institucion': 'SSA',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.410839',
#   'Lon': '-99.151941',
#   '_id': ObjectId('5efacbe00479130f19c03888')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'INSTITUTO  NACIONAL DE CARDIOLOGÍA IGNACIO CHÁVEZ',
#   'Institucion': 'SSA',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.290598',
#   'Lon': '-99.153838',
#   '_id': ObjectId('5efacbe00479130f19c03889')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'PEDIATRICO DE LA VILLA',
#   'Institucion': 'SEDESA',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.487355',
#   'Lon': '-99.114316',
#   '_id': ObjectId('5efacbe00479130f19c0388a')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL VILLA',
#   'Institucion': 'SEDESA',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.480079',
#   'Lon': '-99.103353',
#   '_id': ObjectId('5efacbe00479130f19c0388b')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL MILPA ALTA',
#   'Institucion': 'SEDESA',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.200951',
#   'Lon': '-99.01121',
#   '_id': ObjectId('5efacbe00479130f19c0388c')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 01 CARLOS MC GREGOR (CDMX SUR)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.395912',
#   'Lon': '-99.16161',
#   '_id': ObjectId('5efacbe00479130f19c0388d')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 24 (CDMX NORTE)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.483221',
#   'Lon': '-99.128448',
#   '_id': ObjectId('5efacbe00479130f19c0388e')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 27 (CDMX NORTE)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.454776',
#   'Lon': '-99.140007',
#   '_id': ObjectId('5efacbe00479130f19c0388f')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA C/MF 08 (CDMX SUR)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.337137',
#   'Lon': '-99.200142',
#   '_id': ObjectId('5efacbe00479130f19c03890')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL 02 (CDMX SUR) VILLA COAPA (COY.)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.309194',
#   'Lon': '-99.129593',
#   '_id': ObjectId('5efacbe00479130f19c03891')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA C/MF 29 (S. JUAN ARAGÓN)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.465117',
#   'Lon': '-99.085162',
#   '_id': ObjectId('5efacbe00479130f19c03892')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL REGIONAL 200',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.742905',
#   'Lon': '-98.972971',
#   '_id': ObjectId('5efacbe00479130f19c03893')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 197',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.515133',
#   'Lon': '-98.89145',
#   '_id': ObjectId('5efacbe00479130f19c03894')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 194',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.4703',
#   'Lon': '-99.234208',
#   '_id': ObjectId('5efacbe00479130f19c03895')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 58 (LAS MARGARITAS)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.530797',
#   'Lon': '-99.222446',
#   '_id': ObjectId('5efacbe00479130f19c03896')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 71 (CHALCO)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.259803',
#   'Lon': '-98.893368',
#   '_id': ObjectId('5efacbe00479130f19c03897')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 76 (XALOSTOC)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.526677',
#   'Lon': '-99.082058',
#   '_id': ObjectId('5efacbe00479130f19c03898')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ZONA 98 (COACALCO)',
#   'Institucion': 'IMSS',
#   'Estatus_capacidad_hospitalaria': 'Crítica',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.638165',
#   'Lon': '-99.098892',
#   '_id': ObjectId('5efacbe00479130f19c03899')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HG DARIO FERNANDEZ FIERRO',
#   'Institucion': 'ISSSTE',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.363602',
#   'Lon': '-99.188608',
#   '_id': ObjectId('5efacbe00479130f19c0389a')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE NEZAHUALCOYOTL "GUSTAVO BAZ PRADA"',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.422253',
#   'Lon': '-99.014892',
#   '_id': ObjectId('5efacbe00479130f19c0389b')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE ECATEPEC "JOSÉ MARÍA RODRÍGUEZ"',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.514412',
#   'Lon': '-99.038087',
#   '_id': ObjectId('5efacbe00479130f19c0389c')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL NEZAHUALCOYOTL "LA PERLA"',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.387963',
#   'Lon': '-98.989442',
#   '_id': ObjectId('5efacbe00479130f19c0389d')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE IXTAPALUCA "PEDRO LOPEZ"',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.318829',
#   'Lon': '-98.855366',
#   '_id': ObjectId('5efacbe00479130f19c0389e')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE CHALCO',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.268265',
#   'Lon': '-98.893965',
#   '_id': ObjectId('5efacbe00479130f19c0389f')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL TEXCOCO "GUADALUPE VICTORIA" BICENTENARIO',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Media',
#   'Lat': '19.514309',
#   'Lon': '-98.87175',
#   '_id': ObjectId('5efacbe00479130f19c038a0')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL AMECAMECA "VALENTIN GOMEZ FARIAS"',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Buena',
#   'Estatus_capacidad_UCI': 'Buena',
#   'Lat': '19.144883',
#   'Lon': '-98.785072',
#   '_id': ObjectId('5efacbe00479130f19c038a1')},
#  {'Fecha': '2020-06-25',
#   'Nombre_hospital': 'HOSPITAL GENERAL DE AXAPUSCO',
#   'Institucion': 'EDOMEX',
#   'Estatus_capacidad_hospitalaria': 'Media',
#   'Estatus_capacidad_UCI': 'Crítica',
#   'Lat': '19.732872',
#   'Lon': '-98.769445',
#   '_id': ObjectId('5efacbe00479130f19c038a2')}]

# %%
delegacion_fecha = clean_covid_data.groupby(["FECHA INGRESO","MUNICIPIO RESIDENCIA"]).count().reset_index().rename(columns={'ID_REGISTRO':'CASOS','FECHA INGRESO':'FECHA'}).drop(['SEXO','FECHA DEFUNCION','INTUBADO','EDAD','DIABETES','EPOC','ASMA','INMUNOSUPRESION','HIPERTENSION','CARDIOVASCULAR','OBESIDAD','RENAL CRONICA','TABAQUISMO'],axis=1)
delegacion_fecha = delegacion_fecha[delegacion_fecha["MUNICIPIO RESIDENCIA"] != "NO"]
delegacion_fecha
# Out:
#            FECHA   MUNICIPIO RESIDENCIA  CASOS
# 3     2020-01-29              Iztacalco      1
# 5     2020-02-07          Benito Juárez      1
# 6     2020-02-12  Cuajimalpa de Morelos      1
# 7     2020-02-27      Gustavo A. Madero      1
# 8     2020-02-27             Iztapalapa      1
# ...          ...                    ...    ...
# 1754  2020-06-24                Tlalpan    147
# 1755  2020-06-24                Tláhuac    111
# 1756  2020-06-24    Venustiano Carranza    121
# 1757  2020-06-24             Xochimilco    146
# 1758  2020-06-24         Álvaro Obregón    125
#
# [1641 rows x 3 columns]

# %%
pd.DataFrame.to_csv(delegacion_fecha,'../assets/data/casos_delegacion_fecha.csv',encoding='latin1')
delegacion_fecha.to_json('../assets/data/casos_delegacion_fecha.json',orient='records')

# %%
#COLLECTION
casos_delegacion_fecha=covid.casos_delegacion_fecha

data_dict = delegacion_fecha.to_dict("records")

for record in data_dict:
    casos_delegacion_fecha.insert_one(record)
    
data_dict
# Out:
# [{'FECHA': '2020-01-29',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038a3')},
#  {'FECHA': '2020-02-07',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038a4')},
#  {'FECHA': '2020-02-12',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038a5')},
#  {'FECHA': '2020-02-27',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038a6')},
#  {'FECHA': '2020-02-27',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038a7')},
#  {'FECHA': '2020-02-27',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038a8')},
#  {'FECHA': '2020-03-02',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038a9')},
#  {'FECHA': '2020-03-05',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038aa')},
#  {'FECHA': '2020-03-07',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038ab')},
#  {'FECHA': '2020-03-08',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038ac')},
#  {'FECHA': '2020-03-08',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038ad')},
#  {'FECHA': '2020-03-09',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038ae')},
#  {'FECHA': '2020-03-10',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038af')},
#  {'FECHA': '2020-03-10',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038b0')},
#  {'FECHA': '2020-03-10',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038b1')},
#  {'FECHA': '2020-03-11',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038b2')},
#  {'FECHA': '2020-03-11',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c038b3')},
#  {'FECHA': '2020-03-11',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038b4')},
#  {'FECHA': '2020-03-11',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038b5')},
#  {'FECHA': '2020-03-11',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038b6')},
#  {'FECHA': '2020-03-11',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038b7')},
#  {'FECHA': '2020-03-11',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038b8')},
#  {'FECHA': '2020-03-11',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c038b9')},
#  {'FECHA': '2020-03-11',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038ba')},
#  {'FECHA': '2020-03-11',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038bb')},
#  {'FECHA': '2020-03-12',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038bc')},
#  {'FECHA': '2020-03-12',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c038bd')},
#  {'FECHA': '2020-03-12',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038be')},
#  {'FECHA': '2020-03-12',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038bf')},
#  {'FECHA': '2020-03-12',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c038c0')},
#  {'FECHA': '2020-03-12',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038c1')},
#  {'FECHA': '2020-03-12',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038c2')},
#  {'FECHA': '2020-03-13',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c038c3')},
#  {'FECHA': '2020-03-13',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c038c4')},
#  {'FECHA': '2020-03-13',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038c5')},
#  {'FECHA': '2020-03-13',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038c6')},
#  {'FECHA': '2020-03-13',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038c7')},
#  {'FECHA': '2020-03-13',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c038c8')},
#  {'FECHA': '2020-03-13',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c038c9')},
#  {'FECHA': '2020-03-13',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038ca')},
#  {'FECHA': '2020-03-13',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038cb')},
#  {'FECHA': '2020-03-13',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c038cc')},
#  {'FECHA': '2020-03-14',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038cd')},
#  {'FECHA': '2020-03-14',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038ce')},
#  {'FECHA': '2020-03-14',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c038cf')},
#  {'FECHA': '2020-03-14',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c038d0')},
#  {'FECHA': '2020-03-14',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038d1')},
#  {'FECHA': '2020-03-14',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038d2')},
#  {'FECHA': '2020-03-14',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038d3')},
#  {'FECHA': '2020-03-14',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c038d4')},
#  {'FECHA': '2020-03-14',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038d5')},
#  {'FECHA': '2020-03-14',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c038d6')},
#  {'FECHA': '2020-03-15',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038d7')},
#  {'FECHA': '2020-03-15',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038d8')},
#  {'FECHA': '2020-03-15',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038d9')},
#  {'FECHA': '2020-03-15',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038da')},
#  {'FECHA': '2020-03-15',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c038db')},
#  {'FECHA': '2020-03-15',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038dc')},
#  {'FECHA': '2020-03-15',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038dd')},
#  {'FECHA': '2020-03-16',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038de')},
#  {'FECHA': '2020-03-16',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038df')},
#  {'FECHA': '2020-03-16',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038e0')},
#  {'FECHA': '2020-03-16',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c038e1')},
#  {'FECHA': '2020-03-16',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c038e2')},
#  {'FECHA': '2020-03-16',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 12,
#   '_id': ObjectId('5efacbe10479130f19c038e3')},
#  {'FECHA': '2020-03-16',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038e4')},
#  {'FECHA': '2020-03-16',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038e5')},
#  {'FECHA': '2020-03-16',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038e6')},
#  {'FECHA': '2020-03-16',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c038e7')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038e8')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c038e9')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038ea')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 14,
#   '_id': ObjectId('5efacbe10479130f19c038eb')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c038ec')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c038ed')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038ee')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038ef')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c038f0')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c038f1')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038f2')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038f3')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038f4')},
#  {'FECHA': '2020-03-17',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038f5')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c038f6')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038f7')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038f8')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c038f9')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c038fa')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c038fb')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c038fc')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c038fd')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c038fe')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 12,
#   '_id': ObjectId('5efacbe10479130f19c038ff')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03900')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03901')},
#  {'FECHA': '2020-03-18',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c03902')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03903')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03904')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03905')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c03906')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03907')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c03908')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03909')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0390a')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 16,
#   '_id': ObjectId('5efacbe10479130f19c0390b')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0390c')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c0390d')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0390e')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c0390f')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03910')},
#  {'FECHA': '2020-03-19',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c03911')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03912')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03913')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03914')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 10,
#   '_id': ObjectId('5efacbe10479130f19c03915')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03916')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03917')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03918')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03919')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c0391a')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c0391b')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0391c')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0391d')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0391e')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0391f')},
#  {'FECHA': '2020-03-20',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c03920')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03921')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03922')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03923')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03924')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c03925')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03926')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03927')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03928')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03929')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0392a')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c0392b')},
#  {'FECHA': '2020-03-21',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c0392c')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c0392d')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0392e')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c0392f')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03930')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03931')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03932')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03933')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03934')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03935')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03936')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03937')},
#  {'FECHA': '2020-03-22',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03938')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 10,
#   '_id': ObjectId('5efacbe10479130f19c03939')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c0393a')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c0393b')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c0393c')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c0393d')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c0393e')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c0393f')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c03940')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c03941')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c03942')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03943')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03944')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c03945')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c03946')},
#  {'FECHA': '2020-03-23',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03947')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c03948')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c03949')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 21,
#   '_id': ObjectId('5efacbe10479130f19c0394a')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c0394b')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c0394c')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c0394d')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c0394e')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 10,
#   '_id': ObjectId('5efacbe10479130f19c0394f')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c03950')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03951')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03952')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03953')},
#  {'FECHA': '2020-03-24',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03954')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c03955')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03956')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03957')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 10,
#   '_id': ObjectId('5efacbe10479130f19c03958')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03959')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c0395a')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c0395b')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c0395c')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c0395d')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c0395e')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0395f')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c03960')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03961')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03962')},
#  {'FECHA': '2020-03-25',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03963')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c03964')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c03965')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c03966')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 14,
#   '_id': ObjectId('5efacbe10479130f19c03967')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c03968')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c03969')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c0396a')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c0396b')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c0396c')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c0396d')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c0396e')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c0396f')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c03970')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c03971')},
#  {'FECHA': '2020-03-26',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c03972')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c03973')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c03974')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c03975')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 23,
#   '_id': ObjectId('5efacbe10479130f19c03976')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c03977')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 10,
#   '_id': ObjectId('5efacbe10479130f19c03978')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 12,
#   '_id': ObjectId('5efacbe10479130f19c03979')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c0397a')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c0397b')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c0397c')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c0397d')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c0397e')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c0397f')},
#  {'FECHA': '2020-03-27',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c03980')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c03981')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c03982')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c03983')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c03984')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c03985')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 13,
#   '_id': ObjectId('5efacbe10479130f19c03986')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c03987')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 10,
#   '_id': ObjectId('5efacbe10479130f19c03988')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03989')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c0398a')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c0398b')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c0398c')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0398d')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0398e')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c0398f')},
#  {'FECHA': '2020-03-28',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03990')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c03991')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c03992')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03993')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 24,
#   '_id': ObjectId('5efacbe10479130f19c03994')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03995')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c03996')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03997')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c03998')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03999')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c0399a')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c0399b')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c0399c')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c0399d')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c0399e')},
#  {'FECHA': '2020-03-29',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c0399f')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 15,
#   '_id': ObjectId('5efacbe10479130f19c039a0')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c039a1')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c039a2')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 26,
#   '_id': ObjectId('5efacbe10479130f19c039a3')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c039a4')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 27,
#   '_id': ObjectId('5efacbe10479130f19c039a5')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 14,
#   '_id': ObjectId('5efacbe10479130f19c039a6')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c039a7')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 20,
#   '_id': ObjectId('5efacbe10479130f19c039a8')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c039a9')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c039aa')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 10,
#   '_id': ObjectId('5efacbe10479130f19c039ab')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c039ac')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c039ad')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c039ae')},
#  {'FECHA': '2020-03-30',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c039af')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 19,
#   '_id': ObjectId('5efacbe10479130f19c039b0')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 11,
#   '_id': ObjectId('5efacbe10479130f19c039b1')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c039b2')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 38,
#   '_id': ObjectId('5efacbe10479130f19c039b3')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 13,
#   '_id': ObjectId('5efacbe10479130f19c039b4')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 15,
#   '_id': ObjectId('5efacbe10479130f19c039b5')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 14,
#   '_id': ObjectId('5efacbe10479130f19c039b6')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c039b7')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 12,
#   '_id': ObjectId('5efacbe10479130f19c039b8')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c039b9')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c039ba')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c039bb')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c039bc')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c039bd')},
#  {'FECHA': '2020-03-31',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c039be')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 26,
#   '_id': ObjectId('5efacbe10479130f19c039bf')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c039c0')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c039c1')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 47,
#   '_id': ObjectId('5efacbe10479130f19c039c2')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c039c3')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 24,
#   '_id': ObjectId('5efacbe10479130f19c039c4')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 11,
#   '_id': ObjectId('5efacbe10479130f19c039c5')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 10,
#   '_id': ObjectId('5efacbe10479130f19c039c6')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 12,
#   '_id': ObjectId('5efacbe10479130f19c039c7')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 10,
#   '_id': ObjectId('5efacbe10479130f19c039c8')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c039c9')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c039ca')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c039cb')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c039cc')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c039cd')},
#  {'FECHA': '2020-04-01',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c039ce')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 22,
#   '_id': ObjectId('5efacbe10479130f19c039cf')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c039d0')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c039d1')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 32,
#   '_id': ObjectId('5efacbe10479130f19c039d2')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c039d3')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 22,
#   '_id': ObjectId('5efacbe10479130f19c039d4')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 29,
#   '_id': ObjectId('5efacbe10479130f19c039d5')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 13,
#   '_id': ObjectId('5efacbe10479130f19c039d6')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c039d7')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c039d8')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c039d9')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c039da')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c039db')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c039dc')},
#  {'FECHA': '2020-04-02',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c039dd')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 15,
#   '_id': ObjectId('5efacbe10479130f19c039de')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 15,
#   '_id': ObjectId('5efacbe10479130f19c039df')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 11,
#   '_id': ObjectId('5efacbe10479130f19c039e0')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 41,
#   '_id': ObjectId('5efacbe10479130f19c039e1')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c039e2')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 25,
#   '_id': ObjectId('5efacbe10479130f19c039e3')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 15,
#   '_id': ObjectId('5efacbe10479130f19c039e4')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 14,
#   '_id': ObjectId('5efacbe10479130f19c039e5')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 19,
#   '_id': ObjectId('5efacbe10479130f19c039e6')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c039e7')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c039e8')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 1,
#   '_id': ObjectId('5efacbe10479130f19c039e9')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c039ea')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c039eb')},
#  {'FECHA': '2020-04-03',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 9,
#   '_id': ObjectId('5efacbe10479130f19c039ec')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c039ed')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c039ee')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c039ef')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 25,
#   '_id': ObjectId('5efacbe10479130f19c039f0')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 6,
#   '_id': ObjectId('5efacbe10479130f19c039f1')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 18,
#   '_id': ObjectId('5efacbe10479130f19c039f2')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 12,
#   '_id': ObjectId('5efacbe10479130f19c039f3')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 19,
#   '_id': ObjectId('5efacbe10479130f19c039f4')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c039f5')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c039f6')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c039f7')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c039f8')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c039f9')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c039fa')},
#  {'FECHA': '2020-04-04',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c039fb')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c039fc')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c039fd')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 10,
#   '_id': ObjectId('5efacbe10479130f19c039fe')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 22,
#   '_id': ObjectId('5efacbe10479130f19c039ff')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 8,
#   '_id': ObjectId('5efacbe10479130f19c03a00')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 16,
#   '_id': ObjectId('5efacbe10479130f19c03a01')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 16,
#   '_id': ObjectId('5efacbe10479130f19c03a02')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 12,
#   '_id': ObjectId('5efacbe10479130f19c03a03')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03a04')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 2,
#   '_id': ObjectId('5efacbe10479130f19c03a05')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03a06')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 5,
#   '_id': ObjectId('5efacbe10479130f19c03a07')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 3,
#   '_id': ObjectId('5efacbe10479130f19c03a08')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c03a09')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 7,
#   '_id': ObjectId('5efacbe10479130f19c03a0a')},
#  {'FECHA': '2020-04-05',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 4,
#   '_id': ObjectId('5efacbe10479130f19c03a0b')},
#  {'FECHA': '2020-04-06',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 29,
#   '_id': ObjectId('5efacbe10479130f19c03a0c')},
#  {'FECHA': '2020-04-06',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 10,
#   '_id': ObjectId('5efacbe10479130f19c03a0d')},
#  {'FECHA': '2020-04-06',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 22,
#   '_id': ObjectId('5efacbe10479130f19c03a0e')},
#  {'FECHA': '2020-04-06',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 51,
#   '_id': ObjectId('5efacbe10479130f19c03a0f')},
#  {'FECHA': '2020-04-06',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 13,
#   '_id': ObjectId('5efacbe10479130f19c03a10')},
#  {'FECHA': '2020-04-06',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 42,
#   '_id': ObjectId('5efacbe10479130f19c03a11')},
#  {'FECHA': '2020-04-06',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 29,
#   '_id': ObjectId('5efacbe10479130f19c03a12')},
#  {'FECHA': '2020-04-06',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
# ...
#  {'FECHA': '2020-05-08',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 148,
#   '_id': ObjectId('5efacbe10479130f19c03c11')},
#  {'FECHA': '2020-05-08',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 109,
#   '_id': ObjectId('5efacbe10479130f19c03c12')},
#  {'FECHA': '2020-05-08',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 221,
#   '_id': ObjectId('5efacbe10479130f19c03c13')},
#  {'FECHA': '2020-05-08',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 36,
#   '_id': ObjectId('5efacbe10479130f19c03c14')},
#  {'FECHA': '2020-05-08',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 35,
#   '_id': ObjectId('5efacbe10479130f19c03c15')},
#  {'FECHA': '2020-05-08',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 29,
#   '_id': ObjectId('5efacbe10479130f19c03c16')},
#  {'FECHA': '2020-05-08',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 84,
#   '_id': ObjectId('5efacbe10479130f19c03c17')},
#  {'FECHA': '2020-05-08',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 46,
#   '_id': ObjectId('5efacbe10479130f19c03c18')},
#  {'FECHA': '2020-05-08',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 70,
#   '_id': ObjectId('5efacbe10479130f19c03c19')},
#  {'FECHA': '2020-05-08',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 87,
#   '_id': ObjectId('5efacbe10479130f19c03c1a')},
#  {'FECHA': '2020-05-08',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 44,
#   '_id': ObjectId('5efacbe10479130f19c03c1b')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 71,
#   '_id': ObjectId('5efacbe10479130f19c03c1c')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 43,
#   '_id': ObjectId('5efacbe10479130f19c03c1d')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 38,
#   '_id': ObjectId('5efacbe10479130f19c03c1e')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 82,
#   '_id': ObjectId('5efacbe10479130f19c03c1f')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 31,
#   '_id': ObjectId('5efacbe10479130f19c03c20')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 76,
#   '_id': ObjectId('5efacbe10479130f19c03c21')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 68,
#   '_id': ObjectId('5efacbe10479130f19c03c22')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 135,
#   '_id': ObjectId('5efacbe10479130f19c03c23')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 13,
#   '_id': ObjectId('5efacbe10479130f19c03c24')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 17,
#   '_id': ObjectId('5efacbe10479130f19c03c25')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 19,
#   '_id': ObjectId('5efacbe10479130f19c03c26')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 34,
#   '_id': ObjectId('5efacbe10479130f19c03c27')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 31,
#   '_id': ObjectId('5efacbe10479130f19c03c28')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 25,
#   '_id': ObjectId('5efacbe10479130f19c03c29')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 48,
#   '_id': ObjectId('5efacbe10479130f19c03c2a')},
#  {'FECHA': '2020-05-09',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 36,
#   '_id': ObjectId('5efacbe10479130f19c03c2b')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 84,
#   '_id': ObjectId('5efacbe10479130f19c03c2c')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 31,
#   '_id': ObjectId('5efacbe10479130f19c03c2d')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 40,
#   '_id': ObjectId('5efacbe10479130f19c03c2e')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 63,
#   '_id': ObjectId('5efacbe10479130f19c03c2f')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 22,
#   '_id': ObjectId('5efacbe10479130f19c03c30')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 75,
#   '_id': ObjectId('5efacbe10479130f19c03c31')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 60,
#   '_id': ObjectId('5efacbe10479130f19c03c32')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 94,
#   '_id': ObjectId('5efacbe10479130f19c03c33')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 21,
#   '_id': ObjectId('5efacbe10479130f19c03c34')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 16,
#   '_id': ObjectId('5efacbe10479130f19c03c35')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 23,
#   '_id': ObjectId('5efacbe10479130f19c03c36')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 32,
#   '_id': ObjectId('5efacbe10479130f19c03c37')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 28,
#   '_id': ObjectId('5efacbe10479130f19c03c38')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 33,
#   '_id': ObjectId('5efacbe10479130f19c03c39')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 54,
#   '_id': ObjectId('5efacbe10479130f19c03c3a')},
#  {'FECHA': '2020-05-10',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 29,
#   '_id': ObjectId('5efacbe10479130f19c03c3b')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 143,
#   '_id': ObjectId('5efacbe10479130f19c03c3c')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 68,
#   '_id': ObjectId('5efacbe10479130f19c03c3d')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 95,
#   '_id': ObjectId('5efacbe10479130f19c03c3e')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 130,
#   '_id': ObjectId('5efacbe10479130f19c03c3f')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 84,
#   '_id': ObjectId('5efacbe10479130f19c03c40')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 162,
#   '_id': ObjectId('5efacbe10479130f19c03c41')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 122,
#   '_id': ObjectId('5efacbe10479130f19c03c42')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 188,
#   '_id': ObjectId('5efacbe10479130f19c03c43')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 63,
#   '_id': ObjectId('5efacbe10479130f19c03c44')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 61,
#   '_id': ObjectId('5efacbe10479130f19c03c45')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 28,
#   '_id': ObjectId('5efacbe10479130f19c03c46')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 77,
#   '_id': ObjectId('5efacbe10479130f19c03c47')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 63,
#   '_id': ObjectId('5efacbe10479130f19c03c48')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 74,
#   '_id': ObjectId('5efacbe10479130f19c03c49')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 80,
#   '_id': ObjectId('5efacbe10479130f19c03c4a')},
#  {'FECHA': '2020-05-11',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 61,
#   '_id': ObjectId('5efacbe10479130f19c03c4b')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 160,
#   '_id': ObjectId('5efacbe10479130f19c03c4c')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 59,
#   '_id': ObjectId('5efacbe10479130f19c03c4d')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 96,
#   '_id': ObjectId('5efacbe10479130f19c03c4e')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 99,
#   '_id': ObjectId('5efacbe10479130f19c03c4f')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 68,
#   '_id': ObjectId('5efacbe10479130f19c03c50')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 152,
#   '_id': ObjectId('5efacbe10479130f19c03c51')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 111,
#   '_id': ObjectId('5efacbe10479130f19c03c52')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 185,
#   '_id': ObjectId('5efacbe10479130f19c03c53')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 32,
#   '_id': ObjectId('5efacbe10479130f19c03c54')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 52,
#   '_id': ObjectId('5efacbe10479130f19c03c55')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 31,
#   '_id': ObjectId('5efacbe10479130f19c03c56')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 75,
#   '_id': ObjectId('5efacbe10479130f19c03c57')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 76,
#   '_id': ObjectId('5efacbe10479130f19c03c58')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 91,
#   '_id': ObjectId('5efacbe10479130f19c03c59')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 72,
#   '_id': ObjectId('5efacbe10479130f19c03c5a')},
#  {'FECHA': '2020-05-12',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 79,
#   '_id': ObjectId('5efacbe10479130f19c03c5b')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 152,
#   '_id': ObjectId('5efacbe10479130f19c03c5c')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 46,
#   '_id': ObjectId('5efacbe10479130f19c03c5d')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 77,
#   '_id': ObjectId('5efacbe10479130f19c03c5e')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 133,
#   '_id': ObjectId('5efacbe10479130f19c03c5f')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 76,
#   '_id': ObjectId('5efacbe10479130f19c03c60')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 175,
#   '_id': ObjectId('5efacbe10479130f19c03c61')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 121,
#   '_id': ObjectId('5efacbe10479130f19c03c62')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 209,
#   '_id': ObjectId('5efacbe10479130f19c03c63')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 45,
#   '_id': ObjectId('5efacbe10479130f19c03c64')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 52,
#   '_id': ObjectId('5efacbe10479130f19c03c65')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 38,
#   '_id': ObjectId('5efacbe10479130f19c03c66')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 86,
#   '_id': ObjectId('5efacbe10479130f19c03c67')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 56,
#   '_id': ObjectId('5efacbe10479130f19c03c68')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 87,
#   '_id': ObjectId('5efacbe10479130f19c03c69')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 84,
#   '_id': ObjectId('5efacbe10479130f19c03c6a')},
#  {'FECHA': '2020-05-13',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 70,
#   '_id': ObjectId('5efacbe10479130f19c03c6b')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 154,
#   '_id': ObjectId('5efacbe10479130f19c03c6c')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 62,
#   '_id': ObjectId('5efacbe10479130f19c03c6d')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 67,
#   '_id': ObjectId('5efacbe10479130f19c03c6e')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 138,
#   '_id': ObjectId('5efacbe10479130f19c03c6f')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 55,
#   '_id': ObjectId('5efacbe10479130f19c03c70')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 175,
#   '_id': ObjectId('5efacbe10479130f19c03c71')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 119,
#   '_id': ObjectId('5efacbe10479130f19c03c72')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 191,
#   '_id': ObjectId('5efacbe10479130f19c03c73')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 62,
#   '_id': ObjectId('5efacbe10479130f19c03c74')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 38,
#   '_id': ObjectId('5efacbe10479130f19c03c75')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 26,
#   '_id': ObjectId('5efacbe10479130f19c03c76')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 114,
#   '_id': ObjectId('5efacbe10479130f19c03c77')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 70,
#   '_id': ObjectId('5efacbe10479130f19c03c78')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 74,
#   '_id': ObjectId('5efacbe10479130f19c03c79')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 75,
#   '_id': ObjectId('5efacbe10479130f19c03c7a')},
#  {'FECHA': '2020-05-14',
#   'MUNICIPIO RESIDENCIA': 'Álvaro Obregón',
#   'CASOS': 73,
#   '_id': ObjectId('5efacbe10479130f19c03c7b')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Azcapotzalco',
#   'CASOS': 190,
#   '_id': ObjectId('5efacbe10479130f19c03c7c')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Benito Juárez',
#   'CASOS': 64,
#   '_id': ObjectId('5efacbe10479130f19c03c7d')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Coyoacán',
#   'CASOS': 90,
#   '_id': ObjectId('5efacbe10479130f19c03c7e')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Cuajimalpa de Morelos',
#   'CASOS': 143,
#   '_id': ObjectId('5efacbe10479130f19c03c7f')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Cuauhtémoc',
#   'CASOS': 75,
#   '_id': ObjectId('5efacbe10479130f19c03c80')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Gustavo A. Madero',
#   'CASOS': 172,
#   '_id': ObjectId('5efacbe10479130f19c03c81')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Iztacalco',
#   'CASOS': 160,
#   '_id': ObjectId('5efacbe10479130f19c03c82')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Iztapalapa',
#   'CASOS': 226,
#   '_id': ObjectId('5efacbe10479130f19c03c83')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'La Magdalena Contreras',
#   'CASOS': 39,
#   '_id': ObjectId('5efacbe10479130f19c03c84')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Miguel Hidalgo',
#   'CASOS': 43,
#   '_id': ObjectId('5efacbe10479130f19c03c85')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Milpa Alta',
#   'CASOS': 41,
#   '_id': ObjectId('5efacbe10479130f19c03c86')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Tlalpan',
#   'CASOS': 101,
#   '_id': ObjectId('5efacbe10479130f19c03c87')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Tláhuac',
#   'CASOS': 77,
#   '_id': ObjectId('5efacbe10479130f19c03c88')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Venustiano Carranza',
#   'CASOS': 114,
#   '_id': ObjectId('5efacbe10479130f19c03c89')},
#  {'FECHA': '2020-05-15',
#   'MUNICIPIO RESIDENCIA': 'Xochimilco',
#   'CASOS': 118,
#   '_id': ObjectId('5efacbe10479130f19c03c8a')},
#  ...]

# %%
cases_per_date = clean_covid_data.copy()
cases_per_date = cases_per_date.groupby(['FECHA INGRESO']).count().reset_index().rename(columns={'FECHA INGRESO':'FECHA','ID_REGISTRO':'CASOS_TOTALES'}).drop(['SEXO','FECHA DEFUNCION','MUNICIPIO RESIDENCIA','INTUBADO','EDAD','DIABETES','EPOC','ASMA','INMUNOSUPRESION','HIPERTENSION','CARDIOVASCULAR','OBESIDAD','RENAL CRONICA','TABAQUISMO'],axis=1)
cases_per_date
# Out:
#           FECHA  CASOS_TOTALES
# 0    2020-01-13              1
# 1    2020-01-14              1
# 2    2020-01-28              1
# 3    2020-01-29              1
# 4    2020-01-30              1
# ..          ...            ...
# 118  2020-06-20           4245
# 119  2020-06-21           3121
# 120  2020-06-22          10267
# 121  2020-06-23          10909
# 122  2020-06-24           4760
#
# [123 rows x 2 columns]

# %%
casos_fecha_mujeres = clean_covid_data.copy()
casos_fecha_mujeres = casos_fecha_mujeres[casos_fecha_mujeres["SEXO"]=="MUJER"]
casos_fecha_mujeres = casos_fecha_mujeres.groupby(['FECHA INGRESO']).count().reset_index().rename(columns={'FECHA INGRESO':'FECHA','ID_REGISTRO':'CASOS_MUJERES'}).drop(['SEXO','FECHA DEFUNCION','MUNICIPIO RESIDENCIA','INTUBADO','EDAD','DIABETES','EPOC','ASMA','INMUNOSUPRESION','HIPERTENSION','CARDIOVASCULAR','OBESIDAD','RENAL CRONICA','TABAQUISMO'],axis=1)
casos_fecha_mujeres
# Out:
#           FECHA  CASOS_MUJERES
# 0    2020-01-14              1
# 1    2020-01-29              1
# 2    2020-02-12              1
# 3    2020-02-28              1
# 4    2020-02-29              1
# ..          ...            ...
# 111  2020-06-20           2020
# 112  2020-06-21           1361
# 113  2020-06-22           5184
# 114  2020-06-23           5578
# 115  2020-06-24           2481
#
# [116 rows x 2 columns]

# %%
casos_fecha_hombres = clean_covid_data.copy()
casos_fecha_hombres = casos_fecha_hombres[casos_fecha_hombres["SEXO"]=="HOMBRE"]
casos_fecha_hombres = casos_fecha_hombres.groupby(['FECHA INGRESO']).count().reset_index().rename(columns={'FECHA INGRESO':'FECHA','ID_REGISTRO':'CASOS_HOMBRES'}).drop(['SEXO','FECHA DEFUNCION','MUNICIPIO RESIDENCIA','INTUBADO','EDAD','DIABETES','EPOC','ASMA','INMUNOSUPRESION','HIPERTENSION','CARDIOVASCULAR','OBESIDAD','RENAL CRONICA','TABAQUISMO'],axis=1)
casos_fecha_hombres
# Out:
#           FECHA  CASOS_HOMBRES
# 0    2020-01-13              1
# 1    2020-01-28              1
# 2    2020-01-30              1
# 3    2020-02-07              1
# 4    2020-02-27              4
# ..          ...            ...
# 114  2020-06-20           2225
# 115  2020-06-21           1760
# 116  2020-06-22           5083
# 117  2020-06-23           5331
# 118  2020-06-24           2279
#
# [119 rows x 2 columns]

# %%
casos_diarios_genero = pd.DataFrame.merge(cases_per_date,casos_fecha_mujeres,how='left',on='FECHA')
casos_diarios_genero = pd.DataFrame.merge(casos_diarios_genero,casos_fecha_hombres,how='left',on='FECHA')
casos_diarios_genero = casos_diarios_genero.sort_values(by=["FECHA"],ascending=True).fillna(0)
display(casos_diarios_genero)
# Out:
#           FECHA  CASOS_TOTALES  CASOS_MUJERES  CASOS_HOMBRES
# 0    2020-01-13              1            0.0            1.0
# 1    2020-01-14              1            1.0            0.0
# 2    2020-01-28              1            0.0            1.0
# 3    2020-01-29              1            1.0            0.0
# 4    2020-01-30              1            0.0            1.0
# ..          ...            ...            ...            ...
# 118  2020-06-20           4245         2020.0         2225.0
# 119  2020-06-21           3121         1361.0         1760.0
# 120  2020-06-22          10267         5184.0         5083.0
# 121  2020-06-23          10909         5578.0         5331.0
# 122  2020-06-24           4760         2481.0         2279.0
#
# [123 rows x 4 columns]

# %%
pd.DataFrame.to_csv(casos_diarios_genero,'../assets/data/casos_fecha_ingreso.csv',encoding='latin1')
casos_diarios_genero.to_json('../assets/data/casos_fecha_ingreso.json',orient='records')

# %%
#COLLECTION
casos_fecha_ingreso=covid.casos_fecha_ingreso

data_dict = casos_diarios_genero.to_dict("records")

for record in data_dict:
    casos_fecha_ingreso.insert_one(record)
    
data_dict
# Out:
# [{'FECHA': '2020-01-13',
#   'CASOS_TOTALES': 1,
#   'CASOS_MUJERES': 0.0,
#   'CASOS_HOMBRES': 1.0,
#   '_id': ObjectId('5efacbe20479130f19c03f0c')},
#  {'FECHA': '2020-01-14',
#   'CASOS_TOTALES': 1,
#   'CASOS_MUJERES': 1.0,
#   'CASOS_HOMBRES': 0.0,
#   '_id': ObjectId('5efacbe20479130f19c03f0d')},
#  {'FECHA': '2020-01-28',
#   'CASOS_TOTALES': 1,
#   'CASOS_MUJERES': 0.0,
#   'CASOS_HOMBRES': 1.0,
#   '_id': ObjectId('5efacbe20479130f19c03f0e')},
#  {'FECHA': '2020-01-29',
#   'CASOS_TOTALES': 1,
#   'CASOS_MUJERES': 1.0,
#   'CASOS_HOMBRES': 0.0,
#   '_id': ObjectId('5efacbe20479130f19c03f0f')},
#  {'FECHA': '2020-01-30',
#   'CASOS_TOTALES': 1,
#   'CASOS_MUJERES': 0.0,
#   'CASOS_HOMBRES': 1.0,
#   '_id': ObjectId('5efacbe20479130f19c03f10')},
#  {'FECHA': '2020-02-07',
#   'CASOS_TOTALES': 1,
#   'CASOS_MUJERES': 0.0,
#   'CASOS_HOMBRES': 1.0,
#   '_id': ObjectId('5efacbe20479130f19c03f11')},
#  {'FECHA': '2020-02-12',
#   'CASOS_TOTALES': 1,
#   'CASOS_MUJERES': 1.0,
#   'CASOS_HOMBRES': 0.0,
#   '_id': ObjectId('5efacbe20479130f19c03f12')},
#  {'FECHA': '2020-02-27',
#   'CASOS_TOTALES': 4,
#   'CASOS_MUJERES': 0.0,
#   'CASOS_HOMBRES': 4.0,
#   '_id': ObjectId('5efacbe20479130f19c03f13')},
#  {'FECHA': '2020-02-28',
#   'CASOS_TOTALES': 2,
#   'CASOS_MUJERES': 1.0,
#   'CASOS_HOMBRES': 1.0,
#   '_id': ObjectId('5efacbe20479130f19c03f14')},
#  {'FECHA': '2020-02-29',
#   'CASOS_TOTALES': 1,
#   'CASOS_MUJERES': 1.0,
#   'CASOS_HOMBRES': 0.0,
#   '_id': ObjectId('5efacbe20479130f19c03f15')},
#  {'FECHA': '2020-03-02',
#   'CASOS_TOTALES': 2,
#   'CASOS_MUJERES': 1.0,
#   'CASOS_HOMBRES': 1.0,
#   '_id': ObjectId('5efacbe20479130f19c03f16')},
#  {'FECHA': '2020-03-04',
#   'CASOS_TOTALES': 2,
#   'CASOS_MUJERES': 1.0,
#   'CASOS_HOMBRES': 1.0,
#   '_id': ObjectId('5efacbe20479130f19c03f17')},
#  {'FECHA': '2020-03-05',
#   'CASOS_TOTALES': 1,
#   'CASOS_MUJERES': 0.0,
#   'CASOS_HOMBRES': 1.0,
#   '_id': ObjectId('5efacbe20479130f19c03f18')},
#  {'FECHA': '2020-03-07',
#   'CASOS_TOTALES': 1,
#   'CASOS_MUJERES': 0.0,
#   'CASOS_HOMBRES': 1.0,
#   '_id': ObjectId('5efacbe20479130f19c03f19')},
#  {'FECHA': '2020-03-08',
#   'CASOS_TOTALES': 4,
#   'CASOS_MUJERES': 1.0,
#   'CASOS_HOMBRES': 3.0,
#   '_id': ObjectId('5efacbe20479130f19c03f1a')},
#  {'FECHA': '2020-03-09',
#   'CASOS_TOTALES': 2,
#   'CASOS_MUJERES': 1.0,
#   'CASOS_HOMBRES': 1.0,
#   '_id': ObjectId('5efacbe20479130f19c03f1b')},
#  {'FECHA': '2020-03-10',
#   'CASOS_TOTALES': 9,
#   'CASOS_MUJERES': 4.0,
#   'CASOS_HOMBRES': 5.0,
#   '_id': ObjectId('5efacbe20479130f19c03f1c')},
#  {'FECHA': '2020-03-11',
#   'CASOS_TOTALES': 27,
#   'CASOS_MUJERES': 7.0,
#   'CASOS_HOMBRES': 20.0,
#   '_id': ObjectId('5efacbe20479130f19c03f1d')},
#  {'FECHA': '2020-03-12',
#   'CASOS_TOTALES': 28,
#   'CASOS_MUJERES': 9.0,
#   'CASOS_HOMBRES': 19.0,
#   '_id': ObjectId('5efacbe20479130f19c03f1e')},
#  {'FECHA': '2020-03-13',
#   'CASOS_TOTALES': 60,
#   'CASOS_MUJERES': 25.0,
#   'CASOS_HOMBRES': 35.0,
#   '_id': ObjectId('5efacbe20479130f19c03f1f')},
#  {'FECHA': '2020-03-14',
#   'CASOS_TOTALES': 50,
#   'CASOS_MUJERES': 23.0,
#   'CASOS_HOMBRES': 27.0,
#   '_id': ObjectId('5efacbe20479130f19c03f20')},
#  {'FECHA': '2020-03-15',
#   'CASOS_TOTALES': 36,
#   'CASOS_MUJERES': 17.0,
#   'CASOS_HOMBRES': 19.0,
#   '_id': ObjectId('5efacbe20479130f19c03f21')},
#  {'FECHA': '2020-03-16',
#   'CASOS_TOTALES': 68,
#   'CASOS_MUJERES': 19.0,
#   'CASOS_HOMBRES': 49.0,
#   '_id': ObjectId('5efacbe20479130f19c03f22')},
#  {'FECHA': '2020-03-17',
#   'CASOS_TOTALES': 91,
#   'CASOS_MUJERES': 30.0,
#   'CASOS_HOMBRES': 61.0,
#   '_id': ObjectId('5efacbe20479130f19c03f23')},
#  {'FECHA': '2020-03-18',
#   'CASOS_TOTALES': 99,
#   'CASOS_MUJERES': 35.0,
#   'CASOS_HOMBRES': 64.0,
#   '_id': ObjectId('5efacbe20479130f19c03f24')},
#  {'FECHA': '2020-03-19',
#   'CASOS_TOTALES': 107,
#   'CASOS_MUJERES': 37.0,
#   'CASOS_HOMBRES': 70.0,
#   '_id': ObjectId('5efacbe20479130f19c03f25')},
#  {'FECHA': '2020-03-20',
#   'CASOS_TOTALES': 101,
#   'CASOS_MUJERES': 45.0,
#   'CASOS_HOMBRES': 56.0,
#   '_id': ObjectId('5efacbe20479130f19c03f26')},
#  {'FECHA': '2020-03-21',
#   'CASOS_TOTALES': 66,
#   'CASOS_MUJERES': 34.0,
#   'CASOS_HOMBRES': 32.0,
#   '_id': ObjectId('5efacbe20479130f19c03f27')},
#  {'FECHA': '2020-03-22',
#   'CASOS_TOTALES': 48,
#   'CASOS_MUJERES': 14.0,
#   'CASOS_HOMBRES': 34.0,
#   '_id': ObjectId('5efacbe20479130f19c03f28')},
#  {'FECHA': '2020-03-23',
#   'CASOS_TOTALES': 130,
#   'CASOS_MUJERES': 54.0,
#   'CASOS_HOMBRES': 76.0,
#   '_id': ObjectId('5efacbe20479130f19c03f29')},
#  {'FECHA': '2020-03-24',
#   'CASOS_TOTALES': 167,
#   'CASOS_MUJERES': 78.0,
#   'CASOS_HOMBRES': 89.0,
#   '_id': ObjectId('5efacbe20479130f19c03f2a')},
#  {'FECHA': '2020-03-25',
#   'CASOS_TOTALES': 143,
#   'CASOS_MUJERES': 63.0,
#   'CASOS_HOMBRES': 80.0,
#   '_id': ObjectId('5efacbe20479130f19c03f2b')},
#  {'FECHA': '2020-03-26',
#   'CASOS_TOTALES': 174,
#   'CASOS_MUJERES': 81.0,
#   'CASOS_HOMBRES': 93.0,
#   '_id': ObjectId('5efacbe20479130f19c03f2c')},
#  {'FECHA': '2020-03-27',
#   'CASOS_TOTALES': 213,
#   'CASOS_MUJERES': 91.0,
#   'CASOS_HOMBRES': 122.0,
#   '_id': ObjectId('5efacbe20479130f19c03f2d')},
#  {'FECHA': '2020-03-28',
#   'CASOS_TOTALES': 162,
#   'CASOS_MUJERES': 59.0,
#   'CASOS_HOMBRES': 103.0,
#   '_id': ObjectId('5efacbe20479130f19c03f2e')},
#  {'FECHA': '2020-03-29',
#   'CASOS_TOTALES': 145,
#   'CASOS_MUJERES': 57.0,
#   'CASOS_HOMBRES': 88.0,
#   '_id': ObjectId('5efacbe20479130f19c03f2f')},
#  {'FECHA': '2020-03-30',
#   'CASOS_TOTALES': 312,
#   'CASOS_MUJERES': 138.0,
#   'CASOS_HOMBRES': 174.0,
#   '_id': ObjectId('5efacbe20479130f19c03f30')},
#  {'FECHA': '2020-03-31',
#   'CASOS_TOTALES': 285,
#   'CASOS_MUJERES': 126.0,
#   'CASOS_HOMBRES': 159.0,
#   '_id': ObjectId('5efacbe20479130f19c03f31')},
#  {'FECHA': '2020-04-01',
#   'CASOS_TOTALES': 329,
#   'CASOS_MUJERES': 134.0,
#   'CASOS_HOMBRES': 195.0,
#   '_id': ObjectId('5efacbe20479130f19c03f32')},
#  {'FECHA': '2020-04-02',
#   'CASOS_TOTALES': 308,
#   'CASOS_MUJERES': 144.0,
#   'CASOS_HOMBRES': 164.0,
#   '_id': ObjectId('5efacbe20479130f19c03f33')},
#  {'FECHA': '2020-04-03',
#   'CASOS_TOTALES': 347,
#   'CASOS_MUJERES': 143.0,
#   'CASOS_HOMBRES': 204.0,
#   '_id': ObjectId('5efacbe20479130f19c03f34')},
#  {'FECHA': '2020-04-04',
#   'CASOS_TOTALES': 222,
#   'CASOS_MUJERES': 82.0,
#   'CASOS_HOMBRES': 140.0,
#   '_id': ObjectId('5efacbe20479130f19c03f35')},
#  {'FECHA': '2020-04-05',
#   'CASOS_TOTALES': 228,
#   'CASOS_MUJERES': 93.0,
#   'CASOS_HOMBRES': 135.0,
#   '_id': ObjectId('5efacbe20479130f19c03f36')},
#  {'FECHA': '2020-04-06',
#   'CASOS_TOTALES': 538,
#   'CASOS_MUJERES': 238.0,
#   'CASOS_HOMBRES': 300.0,
#   '_id': ObjectId('5efacbe20479130f19c03f37')},
#  {'FECHA': '2020-04-07',
#   'CASOS_TOTALES': 461,
#   'CASOS_MUJERES': 193.0,
#   'CASOS_HOMBRES': 268.0,
#   '_id': ObjectId('5efacbe20479130f19c03f38')},
#  {'FECHA': '2020-04-08',
#   'CASOS_TOTALES': 530,
#   'CASOS_MUJERES': 239.0,
#   'CASOS_HOMBRES': 291.0,
#   '_id': ObjectId('5efacbe20479130f19c03f39')},
#  {'FECHA': '2020-04-09',
#   'CASOS_TOTALES': 414,
#   'CASOS_MUJERES': 158.0,
#   'CASOS_HOMBRES': 256.0,
#   '_id': ObjectId('5efacbe20479130f19c03f3a')},
#  {'FECHA': '2020-04-10',
#   'CASOS_TOTALES': 500,
#   'CASOS_MUJERES': 207.0,
#   'CASOS_HOMBRES': 293.0,
#   '_id': ObjectId('5efacbe20479130f19c03f3b')},
#  {'FECHA': '2020-04-11',
#   'CASOS_TOTALES': 414,
#   'CASOS_MUJERES': 174.0,
#   'CASOS_HOMBRES': 240.0,
#   '_id': ObjectId('5efacbe20479130f19c03f3c')},
#  {'FECHA': '2020-04-12',
#   'CASOS_TOTALES': 436,
#   'CASOS_MUJERES': 179.0,
#   'CASOS_HOMBRES': 257.0,
#   '_id': ObjectId('5efacbe20479130f19c03f3d')},
#  {'FECHA': '2020-04-13',
#   'CASOS_TOTALES': 859,
#   'CASOS_MUJERES': 347.0,
#   'CASOS_HOMBRES': 512.0,
#   '_id': ObjectId('5efacbe20479130f19c03f3e')},
#  {'FECHA': '2020-04-14',
#   'CASOS_TOTALES': 856,
#   'CASOS_MUJERES': 374.0,
#   'CASOS_HOMBRES': 482.0,
#   '_id': ObjectId('5efacbe20479130f19c03f3f')},
#  {'FECHA': '2020-04-15',
#   'CASOS_TOTALES': 882,
#   'CASOS_MUJERES': 369.0,
#   'CASOS_HOMBRES': 513.0,
#   '_id': ObjectId('5efacbe20479130f19c03f40')},
#  {'FECHA': '2020-04-16',
#   'CASOS_TOTALES': 905,
#   'CASOS_MUJERES': 406.0,
#   'CASOS_HOMBRES': 499.0,
#   '_id': ObjectId('5efacbe20479130f19c03f41')},
#  {'FECHA': '2020-04-17',
#   'CASOS_TOTALES': 1042,
#   'CASOS_MUJERES': 451.0,
#   'CASOS_HOMBRES': 591.0,
#   '_id': ObjectId('5efacbe20479130f19c03f42')},
#  {'FECHA': '2020-04-18',
#   'CASOS_TOTALES': 741,
#   'CASOS_MUJERES': 301.0,
#   'CASOS_HOMBRES': 440.0,
#   '_id': ObjectId('5efacbe20479130f19c03f43')},
#  {'FECHA': '2020-04-19',
#   'CASOS_TOTALES': 694,
#   'CASOS_MUJERES': 259.0,
#   'CASOS_HOMBRES': 435.0,
#   '_id': ObjectId('5efacbe20479130f19c03f44')},
#  {'FECHA': '2020-04-20',
#   'CASOS_TOTALES': 1394,
#   'CASOS_MUJERES': 564.0,
#   'CASOS_HOMBRES': 830.0,
#   '_id': ObjectId('5efacbe20479130f19c03f45')},
#  {'FECHA': '2020-04-21',
#   'CASOS_TOTALES': 1343,
#   'CASOS_MUJERES': 512.0,
#   'CASOS_HOMBRES': 831.0,
#   '_id': ObjectId('5efacbe20479130f19c03f46')},
#  {'FECHA': '2020-04-22',
#   'CASOS_TOTALES': 1289,
#   'CASOS_MUJERES': 518.0,
#   'CASOS_HOMBRES': 771.0,
#   '_id': ObjectId('5efacbe20479130f19c03f47')},
#  {'FECHA': '2020-04-23',
#   'CASOS_TOTALES': 1386,
#   'CASOS_MUJERES': 594.0,
#   'CASOS_HOMBRES': 792.0,
#   '_id': ObjectId('5efacbe20479130f19c03f48')},
#  {'FECHA': '2020-04-24',
#   'CASOS_TOTALES': 1564,
#   'CASOS_MUJERES': 653.0,
#   'CASOS_HOMBRES': 911.0,
#   '_id': ObjectId('5efacbe20479130f19c03f49')},
#  {'FECHA': '2020-04-25',
#   'CASOS_TOTALES': 989,
#   'CASOS_MUJERES': 399.0,
#   'CASOS_HOMBRES': 590.0,
#   '_id': ObjectId('5efacbe20479130f19c03f4a')},
#  {'FECHA': '2020-04-26',
#   'CASOS_TOTALES': 968,
#   'CASOS_MUJERES': 373.0,
#   'CASOS_HOMBRES': 595.0,
#   '_id': ObjectId('5efacbe20479130f19c03f4b')},
#  {'FECHA': '2020-04-27',
#   'CASOS_TOTALES': 1782,
#   'CASOS_MUJERES': 718.0,
#   'CASOS_HOMBRES': 1064.0,
#   '_id': ObjectId('5efacbe20479130f19c03f4c')},
#  {'FECHA': '2020-04-28',
#   'CASOS_TOTALES': 1768,
#   'CASOS_MUJERES': 733.0,
#   'CASOS_HOMBRES': 1035.0,
#   '_id': ObjectId('5efacbe20479130f19c03f4d')},
#  {'FECHA': '2020-04-29',
#   'CASOS_TOTALES': 1745,
#   'CASOS_MUJERES': 700.0,
#   'CASOS_HOMBRES': 1045.0,
#   '_id': ObjectId('5efacbe20479130f19c03f4e')},
#  {'FECHA': '2020-04-30',
#   'CASOS_TOTALES': 1759,
#   'CASOS_MUJERES': 754.0,
#   'CASOS_HOMBRES': 1005.0,
#   '_id': ObjectId('5efacbe20479130f19c03f4f')},
#  {'FECHA': '2020-05-01',
#   'CASOS_TOTALES': 1354,
#   'CASOS_MUJERES': 534.0,
#   'CASOS_HOMBRES': 820.0,
#   '_id': ObjectId('5efacbe20479130f19c03f50')},
#  {'FECHA': '2020-05-02',
#   'CASOS_TOTALES': 1360,
#   'CASOS_MUJERES': 519.0,
#   'CASOS_HOMBRES': 841.0,
#   '_id': ObjectId('5efacbe20479130f19c03f51')},
#  {'FECHA': '2020-05-03',
#   'CASOS_TOTALES': 1241,
#   'CASOS_MUJERES': 454.0,
#   'CASOS_HOMBRES': 787.0,
#   '_id': ObjectId('5efacbe20479130f19c03f52')},
#  {'FECHA': '2020-05-04',
#   'CASOS_TOTALES': 2510,
#   'CASOS_MUJERES': 1118.0,
#   'CASOS_HOMBRES': 1392.0,
#   '_id': ObjectId('5efacbe20479130f19c03f53')},
#  {'FECHA': '2020-05-05',
#   'CASOS_TOTALES': 2189,
#   'CASOS_MUJERES': 977.0,
#   'CASOS_HOMBRES': 1212.0,
#   '_id': ObjectId('5efacbe20479130f19c03f54')},
#  {'FECHA': '2020-05-06',
#   'CASOS_TOTALES': 2380,
#   'CASOS_MUJERES': 1021.0,
#   'CASOS_HOMBRES': 1359.0,
#   '_id': ObjectId('5efacbe20479130f19c03f55')},
#  {'FECHA': '2020-05-07',
#   'CASOS_TOTALES': 2457,
#   'CASOS_MUJERES': 1113.0,
#   'CASOS_HOMBRES': 1344.0,
#   '_id': ObjectId('5efacbe20479130f19c03f56')},
#  {'FECHA': '2020-05-08',
#   'CASOS_TOTALES': 2509,
#   'CASOS_MUJERES': 1125.0,
#   'CASOS_HOMBRES': 1384.0,
#   '_id': ObjectId('5efacbe20479130f19c03f57')},
#  {'FECHA': '2020-05-09',
#   'CASOS_TOTALES': 1587,
#   'CASOS_MUJERES': 645.0,
#   'CASOS_HOMBRES': 942.0,
#   '_id': ObjectId('5efacbe20479130f19c03f58')},
#  {'FECHA': '2020-05-10',
#   'CASOS_TOTALES': 1423,
#   'CASOS_MUJERES': 576.0,
#   'CASOS_HOMBRES': 847.0,
#   '_id': ObjectId('5efacbe20479130f19c03f59')},
#  {'FECHA': '2020-05-11',
#   'CASOS_TOTALES': 3058,
#   'CASOS_MUJERES': 1351.0,
#   'CASOS_HOMBRES': 1707.0,
#   '_id': ObjectId('5efacbe20479130f19c03f5a')},
#  {'FECHA': '2020-05-12',
#   'CASOS_TOTALES': 3021,
#   'CASOS_MUJERES': 1357.0,
#   'CASOS_HOMBRES': 1664.0,
#   '_id': ObjectId('5efacbe20479130f19c03f5b')},
#  {'FECHA': '2020-05-13',
#   'CASOS_TOTALES': 3223,
#   'CASOS_MUJERES': 1466.0,
#   'CASOS_HOMBRES': 1757.0,
#   '_id': ObjectId('5efacbe20479130f19c03f5c')},
#  {'FECHA': '2020-05-14',
#   'CASOS_TOTALES': 3171,
#   'CASOS_MUJERES': 1423.0,
#   'CASOS_HOMBRES': 1748.0,
#   '_id': ObjectId('5efacbe20479130f19c03f5d')},
#  {'FECHA': '2020-05-15',
#   'CASOS_TOTALES': 3624,
#   'CASOS_MUJERES': 1643.0,
#   'CASOS_HOMBRES': 1981.0,
#   '_id': ObjectId('5efacbe20479130f19c03f5e')},
#  {'FECHA': '2020-05-16',
#   'CASOS_TOTALES': 2224,
#   'CASOS_MUJERES': 930.0,
#   'CASOS_HOMBRES': 1294.0,
#   '_id': ObjectId('5efacbe20479130f19c03f5f')},
#  {'FECHA': '2020-05-17',
#   'CASOS_TOTALES': 1680,
#   'CASOS_MUJERES': 668.0,
#   'CASOS_HOMBRES': 1012.0,
#   '_id': ObjectId('5efacbe20479130f19c03f60')},
#  {'FECHA': '2020-05-18',
#   'CASOS_TOTALES': 4217,
#   'CASOS_MUJERES': 1865.0,
#   'CASOS_HOMBRES': 2352.0,
#   '_id': ObjectId('5efacbe20479130f19c03f61')},
#  {'FECHA': '2020-05-19',
#   'CASOS_TOTALES': 3757,
#   'CASOS_MUJERES': 1742.0,
#   'CASOS_HOMBRES': 2015.0,
#   '_id': ObjectId('5efacbe20479130f19c03f62')},
#  {'FECHA': '2020-05-20',
#   'CASOS_TOTALES': 4038,
#   'CASOS_MUJERES': 1855.0,
#   'CASOS_HOMBRES': 2183.0,
#   '_id': ObjectId('5efacbe20479130f19c03f63')},
#  {'FECHA': '2020-05-21',
#   'CASOS_TOTALES': 4100,
#   'CASOS_MUJERES': 1880.0,
#   'CASOS_HOMBRES': 2220.0,
#   '_id': ObjectId('5efacbe20479130f19c03f64')},
#  {'FECHA': '2020-05-22',
#   'CASOS_TOTALES': 4219,
#   'CASOS_MUJERES': 1957.0,
#   'CASOS_HOMBRES': 2262.0,
#   '_id': ObjectId('5efacbe20479130f19c03f65')},
#  {'FECHA': '2020-05-23',
#   'CASOS_TOTALES': 2354,
#   'CASOS_MUJERES': 965.0,
#   'CASOS_HOMBRES': 1389.0,
#   '_id': ObjectId('5efacbe20479130f19c03f66')},
#  {'FECHA': '2020-05-24',
#   'CASOS_TOTALES': 1957,
#   'CASOS_MUJERES': 812.0,
#   'CASOS_HOMBRES': 1145.0,
#   '_id': ObjectId('5efacbe20479130f19c03f67')},
#  {'FECHA': '2020-05-25',
#   'CASOS_TOTALES': 4809,
#   'CASOS_MUJERES': 2217.0,
#   'CASOS_HOMBRES': 2592.0,
#   '_id': ObjectId('5efacbe20479130f19c03f68')},
#  {'FECHA': '2020-05-26',
#   'CASOS_TOTALES': 4533,
#   'CASOS_MUJERES': 2045.0,
#   'CASOS_HOMBRES': 2488.0,
#   '_id': ObjectId('5efacbe20479130f19c03f69')},
#  {'FECHA': '2020-05-27',
#   'CASOS_TOTALES': 4662,
#   'CASOS_MUJERES': 2157.0,
#   'CASOS_HOMBRES': 2505.0,
#   '_id': ObjectId('5efacbe20479130f19c03f6a')},
#  {'FECHA': '2020-05-28',
#   'CASOS_TOTALES': 4440,
#   'CASOS_MUJERES': 2066.0,
#   'CASOS_HOMBRES': 2374.0,
#   '_id': ObjectId('5efacbe20479130f19c03f6b')},
#  {'FECHA': '2020-05-29',
#   'CASOS_TOTALES': 4581,
#   'CASOS_MUJERES': 2117.0,
#   'CASOS_HOMBRES': 2464.0,
#   '_id': ObjectId('5efacbe20479130f19c03f6c')},
#  {'FECHA': '2020-05-30',
#   'CASOS_TOTALES': 2894,
#   'CASOS_MUJERES': 1267.0,
#   'CASOS_HOMBRES': 1627.0,
#   '_id': ObjectId('5efacbe20479130f19c03f6d')},
#  {'FECHA': '2020-05-31',
#   'CASOS_TOTALES': 2161,
#   'CASOS_MUJERES': 890.0,
#   'CASOS_HOMBRES': 1271.0,
#   '_id': ObjectId('5efacbe20479130f19c03f6e')},
#  {'FECHA': '2020-06-01',
#   'CASOS_TOTALES': 5586,
#   'CASOS_MUJERES': 2674.0,
#   'CASOS_HOMBRES': 2912.0,
#   '_id': ObjectId('5efacbe20479130f19c03f6f')},
#  {'FECHA': '2020-06-02',
#   'CASOS_TOTALES': 5083,
#   'CASOS_MUJERES': 2387.0,
#   'CASOS_HOMBRES': 2696.0,
#   '_id': ObjectId('5efacbe20479130f19c03f70')},
#  {'FECHA': '2020-06-03',
#   'CASOS_TOTALES': 5266,
#   'CASOS_MUJERES': 2482.0,
#   'CASOS_HOMBRES': 2784.0,
#   '_id': ObjectId('5efacbe20479130f19c03f71')},
#  {'FECHA': '2020-06-04',
#   'CASOS_TOTALES': 5198,
#   'CASOS_MUJERES': 2435.0,
#   'CASOS_HOMBRES': 2763.0,
#   '_id': ObjectId('5efacbe20479130f19c03f72')},
#  {'FECHA': '2020-06-05',
#   'CASOS_TOTALES': 5399,
#   'CASOS_MUJERES': 2578.0,
#   'CASOS_HOMBRES': 2821.0,
#   '_id': ObjectId('5efacbe20479130f19c03f73')},
#  {'FECHA': '2020-06-06',
#   'CASOS_TOTALES': 3100,
#   'CASOS_MUJERES': 1362.0,
#   'CASOS_HOMBRES': 1738.0,
#   '_id': ObjectId('5efacbe20479130f19c03f74')},
#  {'FECHA': '2020-06-07',
#   'CASOS_TOTALES': 2474,
#   'CASOS_MUJERES': 1156.0,
#   'CASOS_HOMBRES': 1318.0,
#   '_id': ObjectId('5efacbe20479130f19c03f75')},
#  {'FECHA': '2020-06-08',
#   'CASOS_TOTALES': 6519,
#   'CASOS_MUJERES': 3075.0,
#   'CASOS_HOMBRES': 3444.0,
#   '_id': ObjectId('5efacbe20479130f19c03f76')},
#  {'FECHA': '2020-06-09',
#   'CASOS_TOTALES': 6125,
#   'CASOS_MUJERES': 2958.0,
#   'CASOS_HOMBRES': 3167.0,
#   '_id': ObjectId('5efacbe20479130f19c03f77')},
#  {'FECHA': '2020-06-10',
#   'CASOS_TOTALES': 6176,
#   'CASOS_MUJERES': 2899.0,
#   'CASOS_HOMBRES': 3277.0,
#   '_id': ObjectId('5efacbe20479130f19c03f78')},
#  {'FECHA': '2020-06-11',
#   'CASOS_TOTALES': 5896,
#   'CASOS_MUJERES': 2742.0,
#   'CASOS_HOMBRES': 3154.0,
#   '_id': ObjectId('5efacbe20479130f19c03f79')},
#  {'FECHA': '2020-06-12',
#   'CASOS_TOTALES': 6215,
#   'CASOS_MUJERES': 2901.0,
#   'CASOS_HOMBRES': 3314.0,
#   '_id': ObjectId('5efacbe20479130f19c03f7a')},
#  {'FECHA': '2020-06-13',
#   'CASOS_TOTALES': 3295,
#   'CASOS_MUJERES': 1541.0,
#   'CASOS_HOMBRES': 1754.0,
#   '_id': ObjectId('5efacbe20479130f19c03f7b')},
#  {'FECHA': '2020-06-14',
#   'CASOS_TOTALES': 2754,
#   'CASOS_MUJERES': 1250.0,
#   'CASOS_HOMBRES': 1504.0,
#   '_id': ObjectId('5efacbe20479130f19c03f7c')},
#  {'FECHA': '2020-06-15',
#   'CASOS_TOTALES': 7111,
#   'CASOS_MUJERES': 3411.0,
#   'CASOS_HOMBRES': 3700.0,
#   '_id': ObjectId('5efacbe20479130f19c03f7d')},
#  {'FECHA': '2020-06-16',
#   'CASOS_TOTALES': 7074,
#   'CASOS_MUJERES': 3404.0,
#   'CASOS_HOMBRES': 3670.0,
#   '_id': ObjectId('5efacbe20479130f19c03f7e')},
#  {'FECHA': '2020-06-17',
#   'CASOS_TOTALES': 6877,
#   'CASOS_MUJERES': 3374.0,
#   'CASOS_HOMBRES': 3503.0,
#   '_id': ObjectId('5efacbe20479130f19c03f7f')},
#  {'FECHA': '2020-06-18',
#   'CASOS_TOTALES': 7322,
#   'CASOS_MUJERES': 3554.0,
#   'CASOS_HOMBRES': 3768.0,
#   '_id': ObjectId('5efacbe20479130f19c03f80')},
#  {'FECHA': '2020-06-19',
#   'CASOS_TOTALES': 7577,
#   'CASOS_MUJERES': 3719.0,
#   'CASOS_HOMBRES': 3858.0,
#   '_id': ObjectId('5efacbe20479130f19c03f81')},
#  {'FECHA': '2020-06-20',
#   'CASOS_TOTALES': 4245,
#   'CASOS_MUJERES': 2020.0,
#   'CASOS_HOMBRES': 2225.0,
#   '_id': ObjectId('5efacbe20479130f19c03f82')},
#  {'FECHA': '2020-06-21',
#   'CASOS_TOTALES': 3121,
#   'CASOS_MUJERES': 1361.0,
#   'CASOS_HOMBRES': 1760.0,
#   '_id': ObjectId('5efacbe20479130f19c03f83')},
#  {'FECHA': '2020-06-22',
#   'CASOS_TOTALES': 10267,
#   'CASOS_MUJERES': 5184.0,
#   'CASOS_HOMBRES': 5083.0,
#   '_id': ObjectId('5efacbe20479130f19c03f84')},
#  {'FECHA': '2020-06-23',
#   'CASOS_TOTALES': 10909,
#   'CASOS_MUJERES': 5578.0,
#   'CASOS_HOMBRES': 5331.0,
#   '_id': ObjectId('5efacbe20479130f19c03f85')},
#  {'FECHA': '2020-06-24',
#   'CASOS_TOTALES': 4760,
#   'CASOS_MUJERES': 2481.0,
#   'CASOS_HOMBRES': 2279.0,
#   '_id': ObjectId('5efacbe20479130f19c03f86')}]

# %%
bins = [-1, 15, 20, 30, 40, 50, 60, 70, 80, 90, 999]
group_labels=['0-15','16-20','21-30','31-40','41-50','51-60','61-70','71-80','81-90','91+']
analisis_genero = clean_covid_data.copy()
analisis_genero["RANGO DE EDAD"] = pd.cut(analisis_genero["EDAD"], bins, labels=group_labels)
analisis_genero = analisis_genero.groupby(['RANGO DE EDAD']).count().drop(['SEXO','FECHA DEFUNCION','MUNICIPIO RESIDENCIA','FECHA INGRESO','INTUBADO','EDAD','DIABETES','EPOC','ASMA','INMUNOSUPRESION','HIPERTENSION','CARDIOVASCULAR','OBESIDAD','RENAL CRONICA','TABAQUISMO'],axis=1).reset_index()
data=[]
generos = ["MUJER","HOMBRE"]
datos = ["CASOS","DIFUNTOS"]
for dato in datos:
    for genero in generos:
        resumen = clean_covid_data.copy()
        if genero != "TODOS":
            resumen = resumen[resumen["SEXO"]==genero]
        if dato == "DIFUNTOS":
            resumen = resumen[resumen["FECHA DEFUNCION"]!="NO"]
        resumen["RANGO DE EDAD"] = pd.cut(resumen["EDAD"], bins, labels=group_labels)
        resumen = resumen.groupby(['RANGO DE EDAD']).count().rename(columns={'ID_REGISTRO':f'{genero} - {dato}'}).drop(['SEXO','FECHA DEFUNCION','MUNICIPIO RESIDENCIA','FECHA INGRESO','INTUBADO','EDAD','DIABETES','EPOC','ASMA','INMUNOSUPRESION','HIPERTENSION','CARDIOVASCULAR','OBESIDAD','RENAL CRONICA','TABAQUISMO'],axis=1).reset_index()
        analisis_genero = pd.DataFrame.merge(analisis_genero,resumen,how='left',on='RANGO DE EDAD')
genero_casos_ = analisis_genero.drop(['ID_REGISTRO','MUJER - DIFUNTOS','HOMBRE - DIFUNTOS'],axis=1).rename(columns={'RANGO DE EDAD':'age','MUJER - CASOS':'female','HOMBRE - CASOS':'male'})
genero_difuntos_ = analisis_genero.drop(['ID_REGISTRO','MUJER - CASOS','HOMBRE - CASOS'],axis=1).rename(columns={'RANGO DE EDAD':'age','MUJER - DIFUNTOS':'female','HOMBRE - DIFUNTOS':'male'})
display(genero_casos_)
display(genero_difuntos_)
# Out:
#      age  female   male
# 0   0-15    2736   3042
# 1  16-20    2574   2328
# 2  21-30   20114  20212
# 3  31-40   27686  30916
# 4  41-50   26604  31140
# 5  51-60   19825  25644
# 6  61-70   11352  15600
# 7  71-80    5803   8001
# 8  81-90    2285   2735
# 9    91+     366    359
#      age  female  male
# 0   0-15      39    52
# 1  16-20      18    13
# 2  21-30     153   244
# 3  31-40     433  1043
# 4  41-50    1143  2808
# 5  51-60    2040  4497
# 6  61-70    2410  4371
# 7  71-80    1800  2983
# 8  81-90     815  1123
# 9    91+      93   140

# %%
genero_casos_.to_json('../assets/data/genero_casos.json',orient='records')
genero_difuntos_.to_json('../assets/data/genero_difuntos.json',orient='records')

# %%
#COLLECTION
genero_casos=covid.genero_casos

data_dict = genero_casos_.to_dict("records")

for record in data_dict:
    genero_casos.insert_one(record)
    
data_dict

#COLLECTION
genero_difuntos=covid.genero_difuntos

data_dict = genero_difuntos_.to_dict("records")

for record in data_dict:
    genero_difuntos.insert_one(record)
    
data_dict
# Out:
# [{'age': '0-15',
#   'female': 39,
#   'male': 52,
#   '_id': ObjectId('5efacbe30479130f19c03f91')},
#  {'age': '16-20',
#   'female': 18,
#   'male': 13,
#   '_id': ObjectId('5efacbe40479130f19c03f92')},
#  {'age': '21-30',
#   'female': 153,
#   'male': 244,
#   '_id': ObjectId('5efacbe40479130f19c03f93')},
#  {'age': '31-40',
#   'female': 433,
#   'male': 1043,
#   '_id': ObjectId('5efacbe40479130f19c03f94')},
#  {'age': '41-50',
#   'female': 1143,
#   'male': 2808,
#   '_id': ObjectId('5efacbe40479130f19c03f95')},
#  {'age': '51-60',
#   'female': 2040,
#   'male': 4497,
#   '_id': ObjectId('5efacbe40479130f19c03f96')},
#  {'age': '61-70',
#   'female': 2410,
#   'male': 4371,
#   '_id': ObjectId('5efacbe40479130f19c03f97')},
#  {'age': '71-80',
#   'female': 1800,
#   'male': 2983,
#   '_id': ObjectId('5efacbe40479130f19c03f98')},
#  {'age': '81-90',
#   'female': 815,
#   'male': 1123,
#   '_id': ObjectId('5efacbe40479130f19c03f99')},
#  {'age': '91+',
#   'female': 93,
#   'male': 140,
#   '_id': ObjectId('5efacbe40479130f19c03f9a')}]

# %%
generos = ["TODOS","MUJER","HOMBRE"]
condiciones = ["TODOS","SIN CONDICION","DIABETES","EPOC","ASMA","INMUNOSUPRESION","HIPERTENSION","CARDIOVASCULAR","OBESIDAD","RENAL CRONICA","TABAQUISMO"]
datos = ["TODOS","INTUBADOS","DIFUNTOS"]
bins = [-1, 15, 20, 30, 40, 50, 60, 70, 80, 90, 999]
group_labels=['0-15','16-20','21-30','31-40','41-50','51-60','61-70','71-80','81-90','91+']
data=[]
for condicion in condiciones:
    for dato in datos:
        for genero in generos:
            resumen = clean_covid_data.copy()
            if genero != "TODOS":
                resumen = resumen[resumen["SEXO"]==genero]
            if condicion != "TODOS":
                if condicion == "SIN CONDICION":
                    resumen = resumen[(resumen['DIABETES']=="NO") & (resumen['TABAQUISMO']=="NO") & (resumen['EPOC']=="NO") & (resumen['ASMA']=="NO") & (resumen['INMUNOSUPRESION']=="NO") & (resumen['HIPERTENSION']=="NO") & (resumen['CARDIOVASCULAR']=="NO") & (resumen['RENAL CRONICA']=="NO") & (resumen['OBESIDAD']=="NO")]
                else:
                    resumen = resumen[resumen[condicion]=="SI"]
            if dato == "INTUBADOS":
                resumen = resumen[resumen["INTUBADO"]=="SI"]
            if dato == "DIFUNTOS":
                resumen = resumen[resumen["FECHA DEFUNCION"]!="NO"]
            resumen["RANGO DE EDAD"] = pd.cut(resumen["EDAD"], bins, labels=group_labels)
            resumen = resumen.groupby(['RANGO DE EDAD']).count().rename(columns={'ID_REGISTRO':f'{genero} - {condicion} - {dato}'}).drop(['SEXO','FECHA DEFUNCION','MUNICIPIO RESIDENCIA','FECHA INGRESO','INTUBADO','EDAD','DIABETES','EPOC','ASMA','INMUNOSUPRESION','HIPERTENSION','CARDIOVASCULAR','OBESIDAD','RENAL CRONICA','TABAQUISMO'],axis=1).reset_index()
            resumen = resumen.transpose()
            resumen = resumen.rename(columns=resumen.iloc[0])
            resumen = resumen.drop(["RANGO DE EDAD"])
            data.append(resumen)
analisis_enfermedades = pd.concat(data)
analisis_enfermedades["TOTAL"] = analisis_enfermedades["0-15"]+analisis_enfermedades["16-20"]+analisis_enfermedades["21-30"]+analisis_enfermedades["31-40"]+analisis_enfermedades["41-50"]+analisis_enfermedades["51-60"]+analisis_enfermedades["61-70"]+analisis_enfermedades["71-80"]+analisis_enfermedades["81-90"]+analisis_enfermedades["91+"]
analisis_enfermedades = analisis_enfermedades.rename_axis("Grupo").reset_index()
separado = analisis_enfermedades["Grupo"].str.split(" - ", n = 2, expand = True) 
analisis_enfermedades["CONDICION"]= separado[1]
analisis_enfermedades["DATO"]= separado[2]
analisis_enfermedades["GENERO"]= separado[0]
analisis_enfermedades.drop(columns =["Grupo"], inplace = True)
analisis_enfermedades = analisis_enfermedades[['CONDICION','DATO','GENERO','0-15','16-20','21-30','31-40','41-50','51-60','61-70','71-80','81-90','91+','TOTAL']]
display(analisis_enfermedades.head(15))
# Out:
#         CONDICION       DATO  GENERO  0-15 16-20  21-30  31-40  41-50  51-60  \
# 0           TODOS      TODOS   TODOS  5778  4902  40326  58602  57744  45469
# 1           TODOS      TODOS   MUJER  2736  2574  20114  27686  26604  19825
# 2           TODOS      TODOS  HOMBRE  3042  2328  20212  30916  31140  25644
# 3           TODOS  INTUBADOS   TODOS   127    24    180    502   1164   1633
# 4           TODOS  INTUBADOS   MUJER    59    11     62    143    302    490
# 5           TODOS  INTUBADOS  HOMBRE    68    13    118    359    862   1143
# 6           TODOS   DIFUNTOS   TODOS    91    31    397   1476   3951   6537
# 7           TODOS   DIFUNTOS   MUJER    39    18    153    433   1143   2040
# 8           TODOS   DIFUNTOS  HOMBRE    52    13    244   1043   2808   4497
# 9   SIN CONDICION      TODOS   TODOS  5010  3952  29713  38884  31371  19451
# 10  SIN CONDICION      TODOS   MUJER  2411  2106  15342  18985  14788   8237
# 11  SIN CONDICION      TODOS  HOMBRE  2599  1846  14371  19899  16583  11214
# 12  SIN CONDICION  INTUBADOS   TODOS    98     8     87    206    395    471
# 13  SIN CONDICION  INTUBADOS   MUJER    47     2     26     65     90    109
# 14  SIN CONDICION  INTUBADOS  HOMBRE    51     6     61    141    305    362
#
#     61-70  71-80 81-90  91+   TOTAL
# 0   26952  13804  5020  725  259322
# 1   11352   5803  2285  366  119345
# 2   15600   8001  2735  359  139977
# 3    1508    874   270   27    6309
# 4     511    306   109   13    2006
# 5     997    568   161   14    4303
# 6    6781   4783  1938  233   26218
# 7    2410   1800   815   93    8944
# 8    4371   2983  1123  140   17274
# 9    8677   3629  1397  248  142332
# 10   3322   1315   553  127   67186
# 11   5355   2314   844  121   75146
# 12    335    172    65    6    1843
# 13     90     41    17    3     490
# 14    245    131    48    3    1353

# %%
pd.DataFrame.to_csv(analisis_enfermedades,'../assets/data/enfermedades.csv',encoding='latin1')
analisis_enfermedades.to_json('../assets/data/enfermedades.json',orient='records')

# %%
#COLLECTION
enfermedades=covid.enfermedades

data_dict = analisis_enfermedades.to_dict("records")

for record in data_dict:
    enfermedades.insert_one(record)
    
data_dict
# Out:
# [{'CONDICION': 'TODOS',
#   'DATO': 'TODOS',
#   'GENERO': 'TODOS',
#   '0-15': 5778,
#   '16-20': 4902,
#   '21-30': 40326,
#   '31-40': 58602,
#   '41-50': 57744,
#   '51-60': 45469,
#   '61-70': 26952,
#   '71-80': 13804,
#   '81-90': 5020,
#   '91+': 725,
#   'TOTAL': 259322,
#   '_id': ObjectId('5efacbed0479130f19c03f9b')},
#  {'CONDICION': 'TODOS',
#   'DATO': 'TODOS',
#   'GENERO': 'MUJER',
#   '0-15': 2736,
#   '16-20': 2574,
#   '21-30': 20114,
#   '31-40': 27686,
#   '41-50': 26604,
#   '51-60': 19825,
#   '61-70': 11352,
#   '71-80': 5803,
#   '81-90': 2285,
#   '91+': 366,
#   'TOTAL': 119345,
#   '_id': ObjectId('5efacbed0479130f19c03f9c')},
#  {'CONDICION': 'TODOS',
#   'DATO': 'TODOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 3042,
#   '16-20': 2328,
#   '21-30': 20212,
#   '31-40': 30916,
#   '41-50': 31140,
#   '51-60': 25644,
#   '61-70': 15600,
#   '71-80': 8001,
#   '81-90': 2735,
#   '91+': 359,
#   'TOTAL': 139977,
#   '_id': ObjectId('5efacbed0479130f19c03f9d')},
#  {'CONDICION': 'TODOS',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'TODOS',
#   '0-15': 127,
#   '16-20': 24,
#   '21-30': 180,
#   '31-40': 502,
#   '41-50': 1164,
#   '51-60': 1633,
#   '61-70': 1508,
#   '71-80': 874,
#   '81-90': 270,
#   '91+': 27,
#   'TOTAL': 6309,
#   '_id': ObjectId('5efacbed0479130f19c03f9e')},
#  {'CONDICION': 'TODOS',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'MUJER',
#   '0-15': 59,
#   '16-20': 11,
#   '21-30': 62,
#   '31-40': 143,
#   '41-50': 302,
#   '51-60': 490,
#   '61-70': 511,
#   '71-80': 306,
#   '81-90': 109,
#   '91+': 13,
#   'TOTAL': 2006,
#   '_id': ObjectId('5efacbed0479130f19c03f9f')},
#  {'CONDICION': 'TODOS',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 68,
#   '16-20': 13,
#   '21-30': 118,
#   '31-40': 359,
#   '41-50': 862,
#   '51-60': 1143,
#   '61-70': 997,
#   '71-80': 568,
#   '81-90': 161,
#   '91+': 14,
#   'TOTAL': 4303,
#   '_id': ObjectId('5efacbed0479130f19c03fa0')},
#  {'CONDICION': 'TODOS',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'TODOS',
#   '0-15': 91,
#   '16-20': 31,
#   '21-30': 397,
#   '31-40': 1476,
#   '41-50': 3951,
#   '51-60': 6537,
#   '61-70': 6781,
#   '71-80': 4783,
#   '81-90': 1938,
#   '91+': 233,
#   'TOTAL': 26218,
#   '_id': ObjectId('5efacbed0479130f19c03fa1')},
#  {'CONDICION': 'TODOS',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'MUJER',
#   '0-15': 39,
#   '16-20': 18,
#   '21-30': 153,
#   '31-40': 433,
#   '41-50': 1143,
#   '51-60': 2040,
#   '61-70': 2410,
#   '71-80': 1800,
#   '81-90': 815,
#   '91+': 93,
#   'TOTAL': 8944,
#   '_id': ObjectId('5efacbed0479130f19c03fa2')},
#  {'CONDICION': 'TODOS',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 52,
#   '16-20': 13,
#   '21-30': 244,
#   '31-40': 1043,
#   '41-50': 2808,
#   '51-60': 4497,
#   '61-70': 4371,
#   '71-80': 2983,
#   '81-90': 1123,
#   '91+': 140,
#   'TOTAL': 17274,
#   '_id': ObjectId('5efacbed0479130f19c03fa3')},
#  {'CONDICION': 'SIN CONDICION',
#   'DATO': 'TODOS',
#   'GENERO': 'TODOS',
#   '0-15': 5010,
#   '16-20': 3952,
#   '21-30': 29713,
#   '31-40': 38884,
#   '41-50': 31371,
#   '51-60': 19451,
#   '61-70': 8677,
#   '71-80': 3629,
#   '81-90': 1397,
#   '91+': 248,
#   'TOTAL': 142332,
#   '_id': ObjectId('5efacbed0479130f19c03fa4')},
#  {'CONDICION': 'SIN CONDICION',
#   'DATO': 'TODOS',
#   'GENERO': 'MUJER',
#   '0-15': 2411,
#   '16-20': 2106,
#   '21-30': 15342,
#   '31-40': 18985,
#   '41-50': 14788,
#   '51-60': 8237,
#   '61-70': 3322,
#   '71-80': 1315,
#   '81-90': 553,
#   '91+': 127,
#   'TOTAL': 67186,
#   '_id': ObjectId('5efacbed0479130f19c03fa5')},
#  {'CONDICION': 'SIN CONDICION',
#   'DATO': 'TODOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 2599,
#   '16-20': 1846,
#   '21-30': 14371,
#   '31-40': 19899,
#   '41-50': 16583,
#   '51-60': 11214,
#   '61-70': 5355,
#   '71-80': 2314,
#   '81-90': 844,
#   '91+': 121,
#   'TOTAL': 75146,
#   '_id': ObjectId('5efacbed0479130f19c03fa6')},
#  {'CONDICION': 'SIN CONDICION',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'TODOS',
#   '0-15': 98,
#   '16-20': 8,
#   '21-30': 87,
#   '31-40': 206,
#   '41-50': 395,
#   '51-60': 471,
#   '61-70': 335,
#   '71-80': 172,
#   '81-90': 65,
#   '91+': 6,
#   'TOTAL': 1843,
#   '_id': ObjectId('5efacbed0479130f19c03fa7')},
#  {'CONDICION': 'SIN CONDICION',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'MUJER',
#   '0-15': 47,
#   '16-20': 2,
#   '21-30': 26,
#   '31-40': 65,
#   '41-50': 90,
#   '51-60': 109,
#   '61-70': 90,
#   '71-80': 41,
#   '81-90': 17,
#   '91+': 3,
#   'TOTAL': 490,
#   '_id': ObjectId('5efacbed0479130f19c03fa8')},
#  {'CONDICION': 'SIN CONDICION',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 51,
#   '16-20': 6,
#   '21-30': 61,
#   '31-40': 141,
#   '41-50': 305,
#   '51-60': 362,
#   '61-70': 245,
#   '71-80': 131,
#   '81-90': 48,
#   '91+': 3,
#   'TOTAL': 1353,
#   '_id': ObjectId('5efacbed0479130f19c03fa9')},
#  {'CONDICION': 'SIN CONDICION',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'TODOS',
#   '0-15': 69,
#   '16-20': 12,
#   '21-30': 147,
#   '31-40': 549,
#   '41-50': 1330,
#   '51-60': 1980,
#   '61-70': 1729,
#   '71-80': 1071,
#   '81-90': 495,
#   '91+': 59,
#   'TOTAL': 7441,
#   '_id': ObjectId('5efacbed0479130f19c03faa')},
#  {'CONDICION': 'SIN CONDICION',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'MUJER',
#   '0-15': 25,
#   '16-20': 5,
#   '21-30': 50,
#   '31-40': 142,
#   '41-50': 326,
#   '51-60': 479,
#   '61-70': 508,
#   '71-80': 312,
#   '81-90': 170,
#   '91+': 24,
#   'TOTAL': 2041,
#   '_id': ObjectId('5efacbed0479130f19c03fab')},
#  {'CONDICION': 'SIN CONDICION',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 44,
#   '16-20': 7,
#   '21-30': 97,
#   '31-40': 407,
#   '41-50': 1004,
#   '51-60': 1501,
#   '61-70': 1221,
#   '71-80': 759,
#   '81-90': 325,
#   '91+': 35,
#   'TOTAL': 5400,
#   '_id': ObjectId('5efacbed0479130f19c03fac')},
#  {'CONDICION': 'DIABETES',
#   'DATO': 'TODOS',
#   'GENERO': 'TODOS',
#   '0-15': 56,
#   '16-20': 69,
#   '21-30': 682,
#   '31-40': 2993,
#   '41-50': 8252,
#   '51-60': 11568,
#   '61-70': 9687,
#   '71-80': 5238,
#   '81-90': 1514,
#   '91+': 134,
#   'TOTAL': 40193,
#   '_id': ObjectId('5efacbed0479130f19c03fad')},
#  {'CONDICION': 'DIABETES',
#   'DATO': 'TODOS',
#   'GENERO': 'MUJER',
#   '0-15': 25,
#   '16-20': 36,
#   '21-30': 356,
#   '31-40': 1338,
#   '41-50': 3616,
#   '51-60': 5140,
#   '61-70': 4308,
#   '71-80': 2394,
#   '81-90': 775,
#   '91+': 67,
#   'TOTAL': 18055,
#   '_id': ObjectId('5efacbed0479130f19c03fae')},
#  {'CONDICION': 'DIABETES',
#   'DATO': 'TODOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 31,
#   '16-20': 33,
#   '21-30': 326,
#   '31-40': 1655,
#   '41-50': 4636,
#   '51-60': 6428,
#   '61-70': 5379,
#   '71-80': 2844,
#   '81-90': 739,
#   '91+': 67,
#   'TOTAL': 22138,
#   '_id': ObjectId('5efacbed0479130f19c03faf')},
#  {'CONDICION': 'DIABETES',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'TODOS',
#   '0-15': 4,
#   '16-20': 2,
#   '21-30': 15,
#   '31-40': 86,
#   '41-50': 335,
#   '51-60': 617,
#   '61-70': 648,
#   '71-80': 380,
#   '81-90': 84,
#   '91+': 3,
#   'TOTAL': 2174,
#   '_id': ObjectId('5efacbed0479130f19c03fb0')},
#  {'CONDICION': 'DIABETES',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'MUJER',
#   '0-15': 2,
#   '16-20': 1,
#   '21-30': 4,
#   '31-40': 24,
#   '41-50': 104,
#   '51-60': 221,
#   '61-70': 250,
#   '71-80': 152,
#   '81-90': 38,
#   '91+': 0,
#   'TOTAL': 796,
#   '_id': ObjectId('5efacbed0479130f19c03fb1')},
#  {'CONDICION': 'DIABETES',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 2,
#   '16-20': 1,
#   '21-30': 11,
#   '31-40': 62,
#   '41-50': 231,
#   '51-60': 396,
#   '61-70': 398,
#   '71-80': 228,
#   '81-90': 46,
#   '91+': 3,
#   'TOTAL': 1378,
#   '_id': ObjectId('5efacbed0479130f19c03fb2')},
#  {'CONDICION': 'DIABETES',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'TODOS',
#   '0-15': 4,
#   '16-20': 2,
#   '21-30': 48,
#   '31-40': 317,
#   '41-50': 1219,
#   '51-60': 2461,
#   '61-70': 2927,
#   '71-80': 1993,
#   '81-90': 626,
#   '91+': 40,
#   'TOTAL': 9637,
#   '_id': ObjectId('5efacbed0479130f19c03fb3')},
#  {'CONDICION': 'DIABETES',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'MUJER',
#   '0-15': 2,
#   '16-20': 2,
#   '21-30': 23,
#   '31-40': 117,
#   '41-50': 442,
#   '51-60': 890,
#   '61-70': 1139,
#   '71-80': 837,
#   '81-90': 308,
#   '91+': 16,
#   'TOTAL': 3776,
#   '_id': ObjectId('5efacbed0479130f19c03fb4')},
#  {'CONDICION': 'DIABETES',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 2,
#   '16-20': 0,
#   '21-30': 25,
#   '31-40': 200,
#   '41-50': 777,
#   '51-60': 1571,
#   '61-70': 1788,
#   '71-80': 1156,
#   '81-90': 318,
#   '91+': 24,
#   'TOTAL': 5861,
#   '_id': ObjectId('5efacbed0479130f19c03fb5')},
#  {'CONDICION': 'EPOC',
#   'DATO': 'TODOS',
#   'GENERO': 'TODOS',
#   '0-15': 10,
#   '16-20': 6,
#   '21-30': 79,
#   '31-40': 210,
#   '41-50': 429,
#   '51-60': 822,
#   '61-70': 1076,
#   '71-80': 1075,
#   '81-90': 542,
#   '91+': 98,
#   'TOTAL': 4347,
#   '_id': ObjectId('5efacbed0479130f19c03fb6')},
#  {'CONDICION': 'EPOC',
#   'DATO': 'TODOS',
#   'GENERO': 'MUJER',
#   '0-15': 4,
#   '16-20': 4,
#   '21-30': 36,
#   '31-40': 84,
#   '41-50': 195,
#   '51-60': 379,
#   '61-70': 505,
#   '71-80': 523,
#   '81-90': 255,
#   '91+': 44,
#   'TOTAL': 2029,
#   '_id': ObjectId('5efacbed0479130f19c03fb7')},
#  {'CONDICION': 'EPOC',
#   'DATO': 'TODOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 6,
#   '16-20': 2,
#   '21-30': 43,
#   '31-40': 126,
#   '41-50': 234,
#   '51-60': 443,
#   '61-70': 571,
#   '71-80': 552,
#   '81-90': 287,
#   '91+': 54,
#   'TOTAL': 2318,
#   '_id': ObjectId('5efacbed0479130f19c03fb8')},
#  {'CONDICION': 'EPOC',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'TODOS',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 2,
#   '31-40': 7,
#   '41-50': 16,
#   '51-60': 45,
#   '61-70': 64,
#   '71-80': 69,
#   '81-90': 29,
#   '91+': 3,
#   'TOTAL': 235,
#   '_id': ObjectId('5efacbed0479130f19c03fb9')},
#  {'CONDICION': 'EPOC',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'MUJER',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 1,
#   '31-40': 0,
#   '41-50': 6,
#   '51-60': 21,
#   '61-70': 26,
#   '71-80': 33,
#   '81-90': 16,
#   '91+': 2,
#   'TOTAL': 105,
#   '_id': ObjectId('5efacbed0479130f19c03fba')},
#  {'CONDICION': 'EPOC',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 1,
#   '31-40': 7,
#   '41-50': 10,
#   '51-60': 24,
#   '61-70': 38,
#   '71-80': 36,
#   '81-90': 13,
#   '91+': 1,
#   'TOTAL': 130,
#   '_id': ObjectId('5efacbed0479130f19c03fbb')},
#  {'CONDICION': 'EPOC',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'TODOS',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 5,
#   '31-40': 22,
#   '41-50': 76,
#   '51-60': 203,
#   '61-70': 343,
#   '71-80': 403,
#   '81-90': 208,
#   '91+': 31,
#   'TOTAL': 1291,
#   '_id': ObjectId('5efacbed0479130f19c03fbc')},
#  {'CONDICION': 'EPOC',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'MUJER',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 2,
#   '31-40': 3,
#   '41-50': 27,
#   '51-60': 83,
#   '61-70': 133,
#   '71-80': 193,
#   '81-90': 102,
#   '91+': 10,
#   'TOTAL': 553,
#   '_id': ObjectId('5efacbed0479130f19c03fbd')},
#  {'CONDICION': 'EPOC',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 3,
#   '31-40': 19,
#   '41-50': 49,
#   '51-60': 120,
#   '61-70': 210,
#   '71-80': 210,
#   '81-90': 106,
#   '91+': 21,
#   'TOTAL': 738,
#   '_id': ObjectId('5efacbed0479130f19c03fbe')},
#  {'CONDICION': 'ASMA',
#   'DATO': 'TODOS',
#   'GENERO': 'TODOS',
#   '0-15': 207,
#   '16-20': 173,
#   '21-30': 1273,
#   '31-40': 1752,
#   '41-50': 1699,
#   '51-60': 1115,
#   '61-70': 584,
#   '71-80': 258,
#   '81-90': 98,
#   '91+': 9,
#   'TOTAL': 7168,
#   '_id': ObjectId('5efacbed0479130f19c03fbf')},
#  {'CONDICION': 'ASMA',
#   'DATO': 'TODOS',
#   'GENERO': 'MUJER',
#   '0-15': 81,
#   '16-20': 87,
#   '21-30': 717,
#   '31-40': 1054,
#   '41-50': 1099,
#   '51-60': 721,
#   '61-70': 351,
#   '71-80': 147,
#   '81-90': 42,
#   '91+': 7,
#   'TOTAL': 4306,
#   '_id': ObjectId('5efacbed0479130f19c03fc0')},
#  {'CONDICION': 'ASMA',
#   'DATO': 'TODOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 126,
#   '16-20': 86,
#   '21-30': 556,
#   '31-40': 698,
#   '41-50': 600,
#   '51-60': 394,
#   '61-70': 233,
#   '71-80': 111,
#   '81-90': 56,
#   '91+': 2,
#   'TOTAL': 2862,
#   '_id': ObjectId('5efacbed0479130f19c03fc1')},
#  {'CONDICION': 'ASMA',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'TODOS',
#   '0-15': 0,
#   '16-20': 1,
#   '21-30': 7,
#   '31-40': 16,
#   '41-50': 18,
#   '51-60': 28,
#   '61-70': 30,
#   '71-80': 12,
#   '81-90': 5,
#   '91+': 1,
#   'TOTAL': 118,
#   '_id': ObjectId('5efacbed0479130f19c03fc2')},
#  {'CONDICION': 'ASMA',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'MUJER',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 2,
#   '31-40': 7,
#   '41-50': 5,
#   '51-60': 17,
#   '61-70': 12,
#   '71-80': 5,
#   '81-90': 0,
#   '91+': 1,
#   'TOTAL': 49,
#   '_id': ObjectId('5efacbed0479130f19c03fc3')},
#  {'CONDICION': 'ASMA',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 0,
#   '16-20': 1,
#   '21-30': 5,
#   '31-40': 9,
#   '41-50': 13,
#   '51-60': 11,
#   '61-70': 18,
#   '71-80': 7,
#   '81-90': 5,
#   '91+': 0,
#   'TOTAL': 69,
#   '_id': ObjectId('5efacbed0479130f19c03fc4')},
#  {'CONDICION': 'ASMA',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'TODOS',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 15,
#   '31-40': 42,
#   '41-50': 90,
#   '51-60': 133,
#   '61-70': 121,
#   '71-80': 86,
#   '81-90': 27,
#   '91+': 4,
#   'TOTAL': 518,
#   '_id': ObjectId('5efacbed0479130f19c03fc5')},
#  {'CONDICION': 'ASMA',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'MUJER',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 6,
#   '31-40': 20,
#   '41-50': 45,
#   '51-60': 78,
#   '61-70': 65,
#   '71-80': 46,
#   '81-90': 7,
#   '91+': 3,
#   'TOTAL': 270,
#   '_id': ObjectId('5efacbed0479130f19c03fc6')},
#  {'CONDICION': 'ASMA',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 9,
#   '31-40': 22,
#   '41-50': 45,
#   '51-60': 55,
#   '61-70': 56,
#   '71-80': 40,
#   '81-90': 20,
#   '91+': 1,
#   'TOTAL': 248,
#   '_id': ObjectId('5efacbed0479130f19c03fc7')},
#  {'CONDICION': 'INMUNOSUPRESION',
#   'DATO': 'TODOS',
#   'GENERO': 'TODOS',
#   '0-15': 200,
#   '16-20': 72,
#   '21-30': 299,
#   '31-40': 490,
#   '41-50': 691,
#   '51-60': 738,
#   '61-70': 627,
#   '71-80': 347,
#   '81-90': 112,
#   '91+': 21,
#   'TOTAL': 3597,
#   '_id': ObjectId('5efacbed0479130f19c03fc8')},
#  {'CONDICION': 'INMUNOSUPRESION',
#   'DATO': 'TODOS',
#   'GENERO': 'MUJER',
#   '0-15': 96,
#   '16-20': 38,
#   '21-30': 143,
#   '31-40': 243,
#   '41-50': 375,
#   '51-60': 384,
#   '61-70': 319,
#   '71-80': 170,
#   '81-90': 55,
#   '91+': 7,
#   'TOTAL': 1830,
#   '_id': ObjectId('5efacbed0479130f19c03fc9')},
#  {'CONDICION': 'INMUNOSUPRESION',
#   'DATO': 'TODOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 104,
#   '16-20': 34,
#   '21-30': 156,
#   '31-40': 247,
#   '41-50': 316,
#   '51-60': 354,
#   '61-70': 308,
#   '71-80': 177,
#   '81-90': 57,
#   '91+': 14,
#   'TOTAL': 1767,
#   '_id': ObjectId('5efacbed0479130f19c03fca')},
#  {'CONDICION': 'INMUNOSUPRESION',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'TODOS',
#   '0-15': 15,
#   '16-20': 6,
#   '21-30': 7,
#   '31-40': 8,
#   '41-50': 21,
#   '51-60': 36,
#   '61-70': 29,
#   '71-80': 26,
#   '81-90': 6,
#   '91+': 1,
#   'TOTAL': 155,
#   '_id': ObjectId('5efacbed0479130f19c03fcb')},
#  {'CONDICION': 'INMUNOSUPRESION',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'MUJER',
#   '0-15': 4,
#   '16-20': 3,
#   '21-30': 1,
#   '31-40': 6,
#   '41-50': 11,
#   '51-60': 10,
#   '61-70': 16,
#   '71-80': 10,
#   '81-90': 1,
#   '91+': 0,
#   'TOTAL': 62,
#   '_id': ObjectId('5efacbed0479130f19c03fcc')},
#  {'CONDICION': 'INMUNOSUPRESION',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 11,
#   '16-20': 3,
#   '21-30': 6,
#   '31-40': 2,
#   '41-50': 10,
#   '51-60': 26,
#   '61-70': 13,
#   '71-80': 16,
#   '81-90': 5,
#   '91+': 1,
#   'TOTAL': 93,
#   '_id': ObjectId('5efacbed0479130f19c03fcd')},
#  {'CONDICION': 'INMUNOSUPRESION',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'TODOS',
#   '0-15': 8,
#   '16-20': 8,
#   '21-30': 25,
#   '31-40': 49,
#   '41-50': 109,
#   '51-60': 166,
#   '61-70': 201,
#   '71-80': 127,
#   '81-90': 44,
#   '91+': 10,
#   'TOTAL': 747,
#   '_id': ObjectId('5efacbed0479130f19c03fce')},
#  {'CONDICION': 'INMUNOSUPRESION',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'MUJER',
#   '0-15': 6,
#   '16-20': 4,
#   '21-30': 13,
#   '31-40': 19,
#   '41-50': 42,
#   '51-60': 69,
#   '61-70': 90,
#   '71-80': 53,
#   '81-90': 16,
#   '91+': 4,
#   'TOTAL': 316,
#   '_id': ObjectId('5efacbed0479130f19c03fcf')},
#  {'CONDICION': 'INMUNOSUPRESION',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 2,
#   '16-20': 4,
#   '21-30': 12,
#   '31-40': 30,
#   '41-50': 67,
#   '51-60': 97,
#   '61-70': 111,
#   '71-80': 74,
#   '81-90': 28,
#   '91+': 6,
#   'TOTAL': 431,
#   '_id': ObjectId('5efacbed0479130f19c03fd0')},
#  {'CONDICION': 'HIPERTENSION',
#   'DATO': 'TODOS',
#   'GENERO': 'TODOS',
#   '0-15': 51,
#   '16-20': 47,
#   '21-30': 1179,
#   '31-40': 3849,
#   '41-50': 9607,
#   '51-60': 13381,
#   '61-70': 11487,
#   '71-80': 7209,
#   '81-90': 2672,
#   '91+': 333,
#   'TOTAL': 49815,
#   '_id': ObjectId('5efacbed0479130f19c03fd1')},
#  {'CONDICION': 'HIPERTENSION',
#   'DATO': 'TODOS',
#   'GENERO': 'MUJER',
#   '0-15': 24,
#   '16-20': 21,
#   '21-30': 488,
#   '31-40': 1579,
#   '41-50': 4392,
#   '51-60': 6273,
#   '61-70': 5393,
#   '71-80': 3381,
#   '81-90': 1343,
#   '91+': 183,
#   'TOTAL': 23077,
#   '_id': ObjectId('5efacbed0479130f19c03fd2')},
#  {'CONDICION': 'HIPERTENSION',
#   'DATO': 'TODOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 27,
#   '16-20': 26,
#   '21-30': 691,
#   '31-40': 2270,
#   '41-50': 5215,
#   '51-60': 7108,
#   '61-70': 6094,
#   '71-80': 3828,
#   '81-90': 1329,
#   '91+': 150,
#   'TOTAL': 26738,
#   '_id': ObjectId('5efacbed0479130f19c03fd3')},
#  {'CONDICION': 'HIPERTENSION',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'TODOS',
#   '0-15': 2,
#   '16-20': 2,
#   '21-30': 19,
#   '31-40': 63,
#   '41-50': 291,
#   '51-60': 563,
#   '61-70': 680,
#   '71-80': 471,
#   '81-90': 138,
#   '91+': 18,
#   'TOTAL': 2247,
#   '_id': ObjectId('5efacbed0479130f19c03fd4')},
#  {'CONDICION': 'HIPERTENSION',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'MUJER',
#   '0-15': 1,
#   '16-20': 2,
#   '21-30': 11,
#   '31-40': 19,
#   '41-50': 92,
#   '51-60': 209,
#   '61-70': 255,
#   '71-80': 185,
#   '81-90': 70,
#   '91+': 10,
#   'TOTAL': 854,
#   '_id': ObjectId('5efacbed0479130f19c03fd5')},
#  {'CONDICION': 'HIPERTENSION',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 1,
#   '16-20': 0,
#   '21-30': 8,
#   '31-40': 44,
#   '41-50': 199,
#   '51-60': 354,
#   '61-70': 425,
#   '71-80': 286,
#   '81-90': 68,
#   '91+': 8,
#   'TOTAL': 1393,
#   '_id': ObjectId('5efacbed0479130f19c03fd6')},
#  {'CONDICION': 'HIPERTENSION',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'TODOS',
#   '0-15': 4,
#   '16-20': 4,
#   '21-30': 71,
#   '31-40': 280,
#   '41-50': 1150,
#   '51-60': 2488,
#   '61-70': 3196,
#   '71-80': 2608,
#   '81-90': 1064,
#   '91+': 126,
#   'TOTAL': 10991,
#   '_id': ObjectId('5efacbed0479130f19c03fd7')},
#  {'CONDICION': 'HIPERTENSION',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'MUJER',
#   '0-15': 2,
#   '16-20': 4,
#   '21-30': 33,
#   '31-40': 101,
#   '41-50': 409,
#   '51-60': 952,
#   '61-70': 1302,
#   '71-80': 1115,
#   '81-90': 495,
#   '91+': 56,
#   'TOTAL': 4469,
#   '_id': ObjectId('5efacbed0479130f19c03fd8')},
#  {'CONDICION': 'HIPERTENSION',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 2,
#   '16-20': 0,
#   '21-30': 38,
#   '31-40': 179,
#   '41-50': 741,
#   '51-60': 1536,
#   '61-70': 1894,
#   '71-80': 1493,
#   '81-90': 569,
#   '91+': 70,
#   'TOTAL': 6522,
#   '_id': ObjectId('5efacbed0479130f19c03fd9')},
#  {'CONDICION': 'CARDIOVASCULAR',
#   'DATO': 'TODOS',
#   'GENERO': 'TODOS',
#   '0-15': 88,
#   '16-20': 35,
#   '21-30': 248,
#   '31-40': 473,
#   '41-50': 825,
#   '51-60': 1221,
#   '61-70': 1310,
#   '71-80': 1134,
#   '81-90': 530,
#   '91+': 95,
#   'TOTAL': 5959,
#   '_id': ObjectId('5efacbed0479130f19c03fda')},
#  {'CONDICION': 'CARDIOVASCULAR',
#   'DATO': 'TODOS',
#   'GENERO': 'MUJER',
#   '0-15': 43,
#   '16-20': 18,
#   '21-30': 116,
#   '31-40': 228,
#   '41-50': 378,
#   '51-60': 510,
#   '61-70': 518,
#   '71-80': 466,
#   '81-90': 249,
#   '91+': 40,
#   'TOTAL': 2566,
#   '_id': ObjectId('5efacbed0479130f19c03fdb')},
#  {'CONDICION': 'CARDIOVASCULAR',
#   'DATO': 'TODOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 45,
#   '16-20': 17,
#   '21-30': 132,
#   '31-40': 245,
#   '41-50': 447,
#   '51-60': 711,
#   '61-70': 792,
#   '71-80': 668,
#   '81-90': 281,
#   '91+': 55,
#   'TOTAL': 3393,
#   '_id': ObjectId('5efacbed0479130f19c03fdc')},
#  {'CONDICION': 'CARDIOVASCULAR',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'TODOS',
#   '0-15': 8,
#   '16-20': 0,
#   '21-30': 3,
#   '31-40': 4,
#   '41-50': 34,
#   '51-60': 76,
#   '61-70': 77,
#   '71-80': 76,
#   '81-90': 41,
#   '91+': 3,
#   'TOTAL': 322,
#   '_id': ObjectId('5efacbed0479130f19c03fdd')},
#  {'CONDICION': 'CARDIOVASCULAR',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'MUJER',
#   '0-15': 5,
#   '16-20': 0,
#   '21-30': 2,
#   '31-40': 0,
#   '41-50': 9,
#   '51-60': 24,
#   '61-70': 20,
#   '71-80': 30,
#   '81-90': 15,
#   '91+': 1,
#   'TOTAL': 106,
#   '_id': ObjectId('5efacbed0479130f19c03fde')},
#  {'CONDICION': 'CARDIOVASCULAR',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 3,
#   '16-20': 0,
#   '21-30': 1,
#   '31-40': 4,
#   '41-50': 25,
#   '51-60': 52,
#   '61-70': 57,
#   '71-80': 46,
#   '81-90': 26,
#   '91+': 2,
#   'TOTAL': 216,
#   '_id': ObjectId('5efacbed0479130f19c03fdf')},
#  {'CONDICION': 'CARDIOVASCULAR',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'TODOS',
#   '0-15': 4,
#   '16-20': 1,
#   '21-30': 14,
#   '31-40': 32,
#   '41-50': 99,
#   '51-60': 232,
#   '61-70': 387,
#   '71-80': 408,
#   '81-90': 200,
#   '91+': 35,
#   'TOTAL': 1412,
#   '_id': ObjectId('5efacbed0479130f19c03fe0')},
#  {'CONDICION': 'CARDIOVASCULAR',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'MUJER',
#   '0-15': 3,
#   '16-20': 0,
#   '21-30': 6,
#   '31-40': 12,
#   '41-50': 31,
#   '51-60': 91,
#   '61-70': 131,
#   '71-80': 149,
#   '81-90': 87,
#   '91+': 13,
#   'TOTAL': 523,
#   '_id': ObjectId('5efacbed0479130f19c03fe1')},
#  {'CONDICION': 'CARDIOVASCULAR',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 1,
#   '16-20': 1,
#   '21-30': 8,
#   '31-40': 20,
#   '41-50': 68,
#   '51-60': 141,
#   '61-70': 256,
#   '71-80': 259,
#   '81-90': 113,
#   '91+': 22,
#   'TOTAL': 889,
#   '_id': ObjectId('5efacbed0479130f19c03fe2')},
#  {'CONDICION': 'OBESIDAD',
#   'DATO': 'TODOS',
#   'GENERO': 'TODOS',
#   '0-15': 205,
#   '16-20': 405,
#   '21-30': 5340,
#   '31-40': 10760,
#   '41-50': 12931,
#   '51-60': 10298,
#   '61-70': 5652,
#   '71-80': 2397,
#   '81-90': 574,
#   '91+': 51,
#   'TOTAL': 48613,
#   '_id': ObjectId('5efacbed0479130f19c03fe3')},
#  {'CONDICION': 'OBESIDAD',
#   'DATO': 'TODOS',
#   'GENERO': 'MUJER',
#   '0-15': 77,
#   '16-20': 228,
#   '21-30': 2643,
#   '31-40': 4960,
#   '41-50': 6061,
#   '51-60': 4994,
#   '61-70': 2910,
#   '71-80': 1277,
#   '81-90': 330,
#   '91+': 27,
#   'TOTAL': 23507,
#   '_id': ObjectId('5efacbed0479130f19c03fe4')},
#  {'CONDICION': 'OBESIDAD',
#   'DATO': 'TODOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 128,
#   '16-20': 177,
#   '21-30': 2697,
#   '31-40': 5800,
#   '41-50': 6870,
#   '51-60': 5304,
#   '61-70': 2742,
#   '71-80': 1120,
#   '81-90': 244,
#   '91+': 24,
#   'TOTAL': 25106,
#   '_id': ObjectId('5efacbed0479130f19c03fe5')},
#  {'CONDICION': 'OBESIDAD',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'TODOS',
#   '0-15': 2,
#   '16-20': 4,
#   '21-30': 42,
#   '31-40': 178,
#   '41-50': 433,
#   '51-60': 466,
#   '61-70': 411,
#   '71-80': 192,
#   '81-90': 41,
#   '91+': 2,
#   'TOTAL': 1771,
#   '_id': ObjectId('5efacbed0479130f19c03fe6')},
#  {'CONDICION': 'OBESIDAD',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'MUJER',
#   '0-15': 1,
#   '16-20': 3,
#   '21-30': 18,
#   '31-40': 47,
#   '41-50': 111,
#   '51-60': 170,
#   '61-70': 177,
#   '71-80': 93,
#   '81-90': 23,
#   '91+': 2,
#   'TOTAL': 645,
#   '_id': ObjectId('5efacbed0479130f19c03fe7')},
#  {'CONDICION': 'OBESIDAD',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 1,
#   '16-20': 1,
#   '21-30': 24,
#   '31-40': 131,
#   '41-50': 322,
#   '51-60': 296,
#   '61-70': 234,
#   '71-80': 99,
#   '81-90': 18,
#   '91+': 0,
#   'TOTAL': 1126,
#   '_id': ObjectId('5efacbed0479130f19c03fe8')},
#  {'CONDICION': 'OBESIDAD',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'TODOS',
#   '0-15': 6,
#   '16-20': 5,
#   '21-30': 124,
#   '31-40': 531,
#   '41-50': 1268,
#   '51-60': 1759,
#   '61-70': 1607,
#   '71-80': 920,
#   '81-90': 240,
#   '91+': 12,
#   'TOTAL': 6472,
#   '_id': ObjectId('5efacbed0479130f19c03fe9')},
#  {'CONDICION': 'OBESIDAD',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'MUJER',
#   '0-15': 3,
#   '16-20': 4,
#   '21-30': 47,
#   '31-40': 161,
#   '41-50': 374,
#   '51-60': 678,
#   '61-70': 733,
#   '71-80': 461,
#   '81-90': 127,
#   '91+': 4,
#   'TOTAL': 2592,
#   '_id': ObjectId('5efacbed0479130f19c03fea')},
#  {'CONDICION': 'OBESIDAD',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 3,
#   '16-20': 1,
#   '21-30': 77,
#   '31-40': 370,
#   '41-50': 894,
#   '51-60': 1081,
#   '61-70': 874,
#   '71-80': 459,
#   '81-90': 113,
#   '91+': 8,
#   'TOTAL': 3880,
#   '_id': ObjectId('5efacbed0479130f19c03feb')},
#  {'CONDICION': 'RENAL CRONICA',
#   'DATO': 'TODOS',
#   'GENERO': 'TODOS',
#   '0-15': 40,
#   '16-20': 34,
#   '21-30': 362,
#   '31-40': 622,
#   '41-50': 888,
#   '51-60': 1239,
#   '61-70': 1244,
#   '71-80': 754,
#   '81-90': 253,
#   '91+': 33,
#   'TOTAL': 5469,
#   '_id': ObjectId('5efacbed0479130f19c03fec')},
#  {'CONDICION': 'RENAL CRONICA',
#   'DATO': 'TODOS',
#   'GENERO': 'MUJER',
#   '0-15': 21,
#   '16-20': 22,
#   '21-30': 154,
#   '31-40': 264,
#   '41-50': 354,
#   '51-60': 532,
#   '61-70': 532,
#   '71-80': 324,
#   '81-90': 97,
#   '91+': 12,
#   'TOTAL': 2312,
#   '_id': ObjectId('5efacbed0479130f19c03fed')},
#  {'CONDICION': 'RENAL CRONICA',
#   'DATO': 'TODOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 19,
#   '16-20': 12,
#   '21-30': 208,
#   '31-40': 358,
#   '41-50': 534,
#   '51-60': 707,
#   '61-70': 712,
#   '71-80': 430,
#   '81-90': 156,
#   '91+': 21,
#   'TOTAL': 3157,
#   '_id': ObjectId('5efacbed0479130f19c03fee')},
#  {'CONDICION': 'RENAL CRONICA',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'TODOS',
#   '0-15': 1,
#   '16-20': 2,
#   '21-30': 11,
#   '31-40': 16,
#   '41-50': 45,
#   '51-60': 81,
#   '61-70': 83,
#   '71-80': 48,
#   '81-90': 17,
#   '91+': 1,
#   'TOTAL': 305,
#   '_id': ObjectId('5efacbed0479130f19c03fef')},
#  {'CONDICION': 'RENAL CRONICA',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'MUJER',
#   '0-15': 0,
#   '16-20': 1,
#   '21-30': 4,
#   '31-40': 6,
#   '41-50': 12,
#   '51-60': 27,
#   '61-70': 29,
#   '71-80': 24,
#   '81-90': 6,
#   '91+': 0,
#   'TOTAL': 109,
#   '_id': ObjectId('5efacbed0479130f19c03ff0')},
#  {'CONDICION': 'RENAL CRONICA',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 1,
#   '16-20': 1,
#   '21-30': 7,
#   '31-40': 10,
#   '41-50': 33,
#   '51-60': 54,
#   '61-70': 54,
#   '71-80': 24,
#   '81-90': 11,
#   '91+': 1,
#   'TOTAL': 196,
#   '_id': ObjectId('5efacbed0479130f19c03ff1')},
#  {'CONDICION': 'RENAL CRONICA',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'TODOS',
#   '0-15': 2,
#   '16-20': 3,
#   '21-30': 48,
#   '31-40': 102,
#   '41-50': 246,
#   '51-60': 424,
#   '61-70': 482,
#   '71-80': 333,
#   '81-90': 110,
#   '91+': 9,
#   'TOTAL': 1759,
#   '_id': ObjectId('5efacbed0479130f19c03ff2')},
#  {'CONDICION': 'RENAL CRONICA',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'MUJER',
#   '0-15': 1,
#   '16-20': 2,
#   '21-30': 19,
#   '31-40': 39,
#   '41-50': 93,
#   '51-60': 163,
#   '61-70': 189,
#   '71-80': 132,
#   '81-90': 47,
#   '91+': 3,
#   'TOTAL': 688,
#   '_id': ObjectId('5efacbed0479130f19c03ff3')},
#  {'CONDICION': 'RENAL CRONICA',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 1,
#   '16-20': 1,
#   '21-30': 29,
#   '31-40': 63,
#   '41-50': 153,
#   '51-60': 261,
#   '61-70': 293,
#   '71-80': 201,
#   '81-90': 63,
#   '91+': 6,
#   'TOTAL': 1071,
#   '_id': ObjectId('5efacbed0479130f19c03ff4')},
#  {'CONDICION': 'TABAQUISMO',
#   'DATO': 'TODOS',
#   'GENERO': 'TODOS',
#   '0-15': 27,
#   '16-20': 241,
#   '21-30': 3609,
#   '31-40': 5088,
#   '41-50': 4228,
#   '51-60': 3096,
#   '61-70': 2056,
#   '71-80': 1250,
#   '81-90': 418,
#   '91+': 57,
#   'TOTAL': 20070,
#   '_id': ObjectId('5efacbed0479130f19c03ff5')},
#  {'CONDICION': 'TABAQUISMO',
#   'DATO': 'TODOS',
#   'GENERO': 'MUJER',
#   '0-15': 10,
#   '16-20': 80,
#   '21-30': 1154,
#   '31-40': 1676,
#   '41-50': 1273,
#   '51-60': 858,
#   '61-70': 452,
#   '71-80': 256,
#   '81-90': 77,
#   '91+': 16,
#   'TOTAL': 5852,
#   '_id': ObjectId('5efacbed0479130f19c03ff6')},
#  {'CONDICION': 'TABAQUISMO',
#   'DATO': 'TODOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 17,
#   '16-20': 161,
#   '21-30': 2455,
#   '31-40': 3412,
#   '41-50': 2955,
#   '51-60': 2238,
#   '61-70': 1604,
#   '71-80': 994,
#   '81-90': 341,
#   '91+': 41,
#   'TOTAL': 14218,
#   '_id': ObjectId('5efacbed0479130f19c03ff7')},
#  {'CONDICION': 'TABAQUISMO',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'TODOS',
#   '0-15': 0,
#   '16-20': 1,
#   '21-30': 21,
#   '31-40': 46,
#   '41-50': 96,
#   '51-60': 134,
#   '61-70': 133,
#   '71-80': 81,
#   '81-90': 18,
#   '91+': 2,
#   'TOTAL': 532,
#   '_id': ObjectId('5efacbed0479130f19c03ff8')},
#  {'CONDICION': 'TABAQUISMO',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'MUJER',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 5,
#   '31-40': 3,
#   '41-50': 15,
#   '51-60': 17,
#   '61-70': 23,
#   '71-80': 5,
#   '81-90': 3,
#   '91+': 1,
#   'TOTAL': 72,
#   '_id': ObjectId('5efacbed0479130f19c03ff9')},
#  {'CONDICION': 'TABAQUISMO',
#   'DATO': 'INTUBADOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 0,
#   '16-20': 1,
#   '21-30': 16,
#   '31-40': 43,
#   '41-50': 81,
#   '51-60': 117,
#   '61-70': 110,
#   '71-80': 76,
#   '81-90': 15,
#   '91+': 1,
#   'TOTAL': 460,
#   '_id': ObjectId('5efacbed0479130f19c03ffa')},
#  {'CONDICION': 'TABAQUISMO',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'TODOS',
#   '0-15': 0,
#   '16-20': 1,
#   '21-30': 42,
#   '31-40': 126,
#   '41-50': 327,
#   '51-60': 521,
#   '61-70': 601,
#   '71-80': 482,
#   '81-90': 161,
#   '91+': 25,
#   'TOTAL': 2286,
#   '_id': ObjectId('5efacbed0479130f19c03ffb')},
#  {'CONDICION': 'TABAQUISMO',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'MUJER',
#   '0-15': 0,
#   '16-20': 0,
#   '21-30': 8,
#   '31-40': 18,
#   '41-50': 55,
#   '51-60': 80,
#   '61-70': 97,
#   '71-80': 75,
#   '81-90': 32,
#   '91+': 6,
#   'TOTAL': 371,
#   '_id': ObjectId('5efacbed0479130f19c03ffc')},
#  {'CONDICION': 'TABAQUISMO',
#   'DATO': 'DIFUNTOS',
#   'GENERO': 'HOMBRE',
#   '0-15': 0,
#   '16-20': 1,
#   '21-30': 34,
#   '31-40': 108,
#   '41-50': 272,
#   '51-60': 441,
#   '61-70': 504,
#   '71-80': 407,
#   '81-90': 129,
#   '91+': 19,
#   'TOTAL': 1915,
#   '_id': ObjectId('5efacbed0479130f19c03ffd')}]

# %%
afluencia_total_diaria = daily_transport_data.rename(columns={'AFLUENCIA TOTAL\n(cifras preliminares)':'AFLUENCIA TOTAL'})[["FECHA","AFLUENCIA TOTAL"]]
afluencia_total_diaria = afluencia_total_diaria.groupby(["FECHA"]).sum()
afluencia_total_diaria
# Out:
#             AFLUENCIA TOTAL
# FECHA
# 2020-03-01        3459628.0
# 2020-03-02        6932366.0
# 2020-03-03        7125952.0
# 2020-03-04        7173088.0
# 2020-03-05        7197222.0
# ...                     ...
# 2020-06-22        2275450.0
# 2020-06-23        2309407.0
# 2020-06-24        2404465.0
# 2020-06-25        1908987.0
# 2020-06-26              0.0
#
# [118 rows x 1 columns]

# %%
casos_afluencia_diaria = pd.DataFrame.merge(cases_per_date,afluencia_total_diaria,how='left',on='FECHA')
casos_afluencia_diaria
# Out:
#           FECHA  CASOS_TOTALES  AFLUENCIA TOTAL
# 0    2020-01-13              1              NaN
# 1    2020-01-14              1              NaN
# 2    2020-01-28              1              NaN
# 3    2020-01-29              1              NaN
# 4    2020-01-30              1              NaN
# ..          ...            ...              ...
# 118  2020-06-20           4245        1938173.0
# 119  2020-06-21           3121        1191119.0
# 120  2020-06-22          10267        2275450.0
# 121  2020-06-23          10909        2309407.0
# 122  2020-06-24           4760        2404465.0
#
# [123 rows x 3 columns]

# %%
pd.DataFrame.to_csv(casos_afluencia_diaria,'../assets/data/casos_vs_afluencia_diaria.csv',encoding='latin1')
casos_afluencia_diaria.to_json('../assets/data/casos_vs_afluencia_diaria.json',orient='records')

# %%
#COLLECTION
casos_vs_afluencia_diaria=covid.casos_vs_afluencia_diaria

data_dict = casos_afluencia_diaria.to_dict("records")

for record in data_dict:
    casos_vs_afluencia_diaria.insert_one(record)
    
data_dict
# Out:
# [{'FECHA': '2020-01-13',
#   'CASOS_TOTALES': 1,
#   'AFLUENCIA TOTAL': nan,
#   '_id': ObjectId('5efacbed0479130f19c03ffe')},
#  {'FECHA': '2020-01-14',
#   'CASOS_TOTALES': 1,
#   'AFLUENCIA TOTAL': nan,
#   '_id': ObjectId('5efacbee0479130f19c03fff')},
#  {'FECHA': '2020-01-28',
#   'CASOS_TOTALES': 1,
#   'AFLUENCIA TOTAL': nan,
#   '_id': ObjectId('5efacbee0479130f19c04000')},
#  {'FECHA': '2020-01-29',
#   'CASOS_TOTALES': 1,
#   'AFLUENCIA TOTAL': nan,
#   '_id': ObjectId('5efacbee0479130f19c04001')},
#  {'FECHA': '2020-01-30',
#   'CASOS_TOTALES': 1,
#   'AFLUENCIA TOTAL': nan,
#   '_id': ObjectId('5efacbee0479130f19c04002')},
#  {'FECHA': '2020-02-07',
#   'CASOS_TOTALES': 1,
#   'AFLUENCIA TOTAL': nan,
#   '_id': ObjectId('5efacbee0479130f19c04003')},
#  {'FECHA': '2020-02-12',
#   'CASOS_TOTALES': 1,
#   'AFLUENCIA TOTAL': nan,
#   '_id': ObjectId('5efacbee0479130f19c04004')},
#  {'FECHA': '2020-02-27',
#   'CASOS_TOTALES': 4,
#   'AFLUENCIA TOTAL': nan,
#   '_id': ObjectId('5efacbee0479130f19c04005')},
#  {'FECHA': '2020-02-28',
#   'CASOS_TOTALES': 2,
#   'AFLUENCIA TOTAL': nan,
#   '_id': ObjectId('5efacbee0479130f19c04006')},
#  {'FECHA': '2020-02-29',
#   'CASOS_TOTALES': 1,
#   'AFLUENCIA TOTAL': nan,
#   '_id': ObjectId('5efacbee0479130f19c04007')},
#  {'FECHA': '2020-03-02',
#   'CASOS_TOTALES': 2,
#   'AFLUENCIA TOTAL': 6932366.0,
#   '_id': ObjectId('5efacbee0479130f19c04008')},
#  {'FECHA': '2020-03-04',
#   'CASOS_TOTALES': 2,
#   'AFLUENCIA TOTAL': 7173088.0,
#   '_id': ObjectId('5efacbee0479130f19c04009')},
#  {'FECHA': '2020-03-05',
#   'CASOS_TOTALES': 1,
#   'AFLUENCIA TOTAL': 7197222.0,
#   '_id': ObjectId('5efacbee0479130f19c0400a')},
#  {'FECHA': '2020-03-07',
#   'CASOS_TOTALES': 1,
#   'AFLUENCIA TOTAL': 5407096.0,
#   '_id': ObjectId('5efacbee0479130f19c0400b')},
#  {'FECHA': '2020-03-08',
#   'CASOS_TOTALES': 4,
#   'AFLUENCIA TOTAL': 3485107.0,
#   '_id': ObjectId('5efacbee0479130f19c0400c')},
#  {'FECHA': '2020-03-09',
#   'CASOS_TOTALES': 2,
#   'AFLUENCIA TOTAL': 4986447.0,
#   '_id': ObjectId('5efacbee0479130f19c0400d')},
#  {'FECHA': '2020-03-10',
#   'CASOS_TOTALES': 9,
#   'AFLUENCIA TOTAL': 7099894.0,
#   '_id': ObjectId('5efacbee0479130f19c0400e')},
#  {'FECHA': '2020-03-11',
#   'CASOS_TOTALES': 27,
#   'AFLUENCIA TOTAL': 7040110.0,
#   '_id': ObjectId('5efacbee0479130f19c0400f')},
#  {'FECHA': '2020-03-12',
#   'CASOS_TOTALES': 28,
#   'AFLUENCIA TOTAL': 7074400.0,
#   '_id': ObjectId('5efacbee0479130f19c04010')},
#  {'FECHA': '2020-03-13',
#   'CASOS_TOTALES': 60,
#   'AFLUENCIA TOTAL': 7264538.0,
#   '_id': ObjectId('5efacbee0479130f19c04011')},
#  {'FECHA': '2020-03-14',
#   'CASOS_TOTALES': 50,
#   'AFLUENCIA TOTAL': 5137139.0,
#   '_id': ObjectId('5efacbee0479130f19c04012')},
#  {'FECHA': '2020-03-15',
#   'CASOS_TOTALES': 36,
#   'AFLUENCIA TOTAL': 3193518.0,
#   '_id': ObjectId('5efacbee0479130f19c04013')},
#  {'FECHA': '2020-03-16',
#   'CASOS_TOTALES': 68,
#   'AFLUENCIA TOTAL': 3630784.0,
#   '_id': ObjectId('5efacbee0479130f19c04014')},
#  {'FECHA': '2020-03-17',
#   'CASOS_TOTALES': 91,
#   'AFLUENCIA TOTAL': 6137483.0,
#   '_id': ObjectId('5efacbee0479130f19c04015')},
#  {'FECHA': '2020-03-18',
#   'CASOS_TOTALES': 99,
#   'AFLUENCIA TOTAL': 5859717.0,
#   '_id': ObjectId('5efacbee0479130f19c04016')},
#  {'FECHA': '2020-03-19',
#   'CASOS_TOTALES': 107,
#   'AFLUENCIA TOTAL': 5562298.0,
#   '_id': ObjectId('5efacbee0479130f19c04017')},
#  {'FECHA': '2020-03-20',
#   'CASOS_TOTALES': 101,
#   'AFLUENCIA TOTAL': 5349875.0,
#   '_id': ObjectId('5efacbee0479130f19c04018')},
#  {'FECHA': '2020-03-21',
#   'CASOS_TOTALES': 66,
#   'AFLUENCIA TOTAL': 3771191.0,
#   '_id': ObjectId('5efacbee0479130f19c04019')},
#  {'FECHA': '2020-03-22',
#   'CASOS_TOTALES': 48,
#   'AFLUENCIA TOTAL': 2279048.0,
#   '_id': ObjectId('5efacbee0479130f19c0401a')},
#  {'FECHA': '2020-03-23',
#   'CASOS_TOTALES': 130,
#   'AFLUENCIA TOTAL': 4318569.0,
#   '_id': ObjectId('5efacbee0479130f19c0401b')},
#  {'FECHA': '2020-03-24',
#   'CASOS_TOTALES': 167,
#   'AFLUENCIA TOTAL': 3903234.0,
#   '_id': ObjectId('5efacbee0479130f19c0401c')},
#  {'FECHA': '2020-03-25',
#   'CASOS_TOTALES': 143,
#   'AFLUENCIA TOTAL': 3858129.0,
#   '_id': ObjectId('5efacbee0479130f19c0401d')},
#  {'FECHA': '2020-03-26',
#   'CASOS_TOTALES': 174,
#   'AFLUENCIA TOTAL': 3702915.0,
#   '_id': ObjectId('5efacbee0479130f19c0401e')},
#  {'FECHA': '2020-03-27',
#   'CASOS_TOTALES': 213,
#   'AFLUENCIA TOTAL': 3514949.0,
#   '_id': ObjectId('5efacbee0479130f19c0401f')},
#  {'FECHA': '2020-03-28',
#   'CASOS_TOTALES': 162,
#   'AFLUENCIA TOTAL': 2707991.0,
#   '_id': ObjectId('5efacbee0479130f19c04020')},
#  {'FECHA': '2020-03-29',
#   'CASOS_TOTALES': 145,
#   'AFLUENCIA TOTAL': 1789310.0,
#   '_id': ObjectId('5efacbee0479130f19c04021')},
#  {'FECHA': '2020-03-30',
#   'CASOS_TOTALES': 312,
#   'AFLUENCIA TOTAL': 3266590.0,
#   '_id': ObjectId('5efacbee0479130f19c04022')},
#  {'FECHA': '2020-03-31',
#   'CASOS_TOTALES': 285,
#   'AFLUENCIA TOTAL': 3211527.0,
#   '_id': ObjectId('5efacbee0479130f19c04023')},
#  {'FECHA': '2020-04-01',
#   'CASOS_TOTALES': 329,
#   'AFLUENCIA TOTAL': 3043357.0,
#   '_id': ObjectId('5efacbee0479130f19c04024')},
#  {'FECHA': '2020-04-02',
#   'CASOS_TOTALES': 308,
#   'AFLUENCIA TOTAL': 2825813.0,
#   '_id': ObjectId('5efacbee0479130f19c04025')},
#  {'FECHA': '2020-04-03',
#   'CASOS_TOTALES': 347,
#   'AFLUENCIA TOTAL': 2778256.0,
#   '_id': ObjectId('5efacbee0479130f19c04026')},
#  {'FECHA': '2020-04-04',
#   'CASOS_TOTALES': 222,
#   'AFLUENCIA TOTAL': 2108601.0,
#   '_id': ObjectId('5efacbee0479130f19c04027')},
#  {'FECHA': '2020-04-05',
#   'CASOS_TOTALES': 228,
#   'AFLUENCIA TOTAL': 1304044.0,
#   '_id': ObjectId('5efacbee0479130f19c04028')},
#  {'FECHA': '2020-04-06',
#   'CASOS_TOTALES': 538,
#   'AFLUENCIA TOTAL': 2344082.0,
#   '_id': ObjectId('5efacbee0479130f19c04029')},
#  {'FECHA': '2020-04-07',
#   'CASOS_TOTALES': 461,
#   'AFLUENCIA TOTAL': 2224678.0,
#   '_id': ObjectId('5efacbee0479130f19c0402a')},
#  {'FECHA': '2020-04-08',
#   'CASOS_TOTALES': 530,
#   'AFLUENCIA TOTAL': 2217318.0,
#   '_id': ObjectId('5efacbee0479130f19c0402b')},
#  {'FECHA': '2020-04-09',
#   'CASOS_TOTALES': 414,
#   'AFLUENCIA TOTAL': 1653108.0,
#   '_id': ObjectId('5efacbee0479130f19c0402c')},
#  {'FECHA': '2020-04-10',
#   'CASOS_TOTALES': 500,
#   'AFLUENCIA TOTAL': 1203611.0,
#   '_id': ObjectId('5efacbee0479130f19c0402d')},
#  {'FECHA': '2020-04-11',
#   'CASOS_TOTALES': 414,
#   'AFLUENCIA TOTAL': 1280280.0,
#   '_id': ObjectId('5efacbee0479130f19c0402e')},
#  {'FECHA': '2020-04-12',
#   'CASOS_TOTALES': 436,
#   'AFLUENCIA TOTAL': 1003881.0,
#   '_id': ObjectId('5efacbee0479130f19c0402f')},
#  {'FECHA': '2020-04-13',
#   'CASOS_TOTALES': 859,
#   'AFLUENCIA TOTAL': 2314408.0,
#   '_id': ObjectId('5efacbee0479130f19c04030')},
#  {'FECHA': '2020-04-14',
#   'CASOS_TOTALES': 856,
#   'AFLUENCIA TOTAL': 2271475.0,
#   '_id': ObjectId('5efacbee0479130f19c04031')},
#  {'FECHA': '2020-04-15',
#   'CASOS_TOTALES': 882,
#   'AFLUENCIA TOTAL': 2317161.0,
#   '_id': ObjectId('5efacbee0479130f19c04032')},
#  {'FECHA': '2020-04-16',
#   'CASOS_TOTALES': 905,
#   'AFLUENCIA TOTAL': 2226449.0,
#   '_id': ObjectId('5efacbee0479130f19c04033')},
#  {'FECHA': '2020-04-17',
#   'CASOS_TOTALES': 1042,
#   'AFLUENCIA TOTAL': 2260529.0,
#   '_id': ObjectId('5efacbee0479130f19c04034')},
#  {'FECHA': '2020-04-18',
#   'CASOS_TOTALES': 741,
#   'AFLUENCIA TOTAL': 1756806.0,
#   '_id': ObjectId('5efacbee0479130f19c04035')},
#  {'FECHA': '2020-04-19',
#   'CASOS_TOTALES': 694,
#   'AFLUENCIA TOTAL': 1142562.0,
#   '_id': ObjectId('5efacbee0479130f19c04036')},
#  {'FECHA': '2020-04-20',
#   'CASOS_TOTALES': 1394,
#   'AFLUENCIA TOTAL': 2246950.0,
#   '_id': ObjectId('5efacbee0479130f19c04037')},
#  {'FECHA': '2020-04-21',
#   'CASOS_TOTALES': 1343,
#   'AFLUENCIA TOTAL': 2150661.0,
#   '_id': ObjectId('5efacbee0479130f19c04038')},
#  {'FECHA': '2020-04-22',
#   'CASOS_TOTALES': 1289,
#   'AFLUENCIA TOTAL': 2128745.0,
#   '_id': ObjectId('5efacbee0479130f19c04039')},
#  {'FECHA': '2020-04-23',
#   'CASOS_TOTALES': 1386,
#   'AFLUENCIA TOTAL': 2024556.0,
#   '_id': ObjectId('5efacbee0479130f19c0403a')},
#  {'FECHA': '2020-04-24',
#   'CASOS_TOTALES': 1564,
#   'AFLUENCIA TOTAL': 2055118.0,
#   '_id': ObjectId('5efacbee0479130f19c0403b')},
#  {'FECHA': '2020-04-25',
#   'CASOS_TOTALES': 989,
#   'AFLUENCIA TOTAL': 1581555.0,
#   '_id': ObjectId('5efacbee0479130f19c0403c')},
#  {'FECHA': '2020-04-26',
#   'CASOS_TOTALES': 968,
#   'AFLUENCIA TOTAL': 1002542.0,
#   '_id': ObjectId('5efacbee0479130f19c0403d')},
#  {'FECHA': '2020-04-27',
#   'CASOS_TOTALES': 1782,
#   'AFLUENCIA TOTAL': 1997764.0,
#   '_id': ObjectId('5efacbee0479130f19c0403e')},
#  {'FECHA': '2020-04-28',
#   'CASOS_TOTALES': 1768,
#   'AFLUENCIA TOTAL': 1951302.0,
#   '_id': ObjectId('5efacbee0479130f19c0403f')},
#  {'FECHA': '2020-04-29',
#   'CASOS_TOTALES': 1745,
#   'AFLUENCIA TOTAL': 1967056.0,
#   '_id': ObjectId('5efacbee0479130f19c04040')},
#  {'FECHA': '2020-04-30',
#   'CASOS_TOTALES': 1759,
#   'AFLUENCIA TOTAL': 2000201.0,
#   '_id': ObjectId('5efacbee0479130f19c04041')},
#  {'FECHA': '2020-05-01',
#   'CASOS_TOTALES': 1354,
#   'AFLUENCIA TOTAL': 1461183.0,
#   '_id': ObjectId('5efacbee0479130f19c04042')},
#  {'FECHA': '2020-05-02',
#   'CASOS_TOTALES': 1360,
#   'AFLUENCIA TOTAL': 1442196.0,
#   '_id': ObjectId('5efacbee0479130f19c04043')},
#  {'FECHA': '2020-05-03',
#   'CASOS_TOTALES': 1241,
#   'AFLUENCIA TOTAL': 936328.0,
#   '_id': ObjectId('5efacbee0479130f19c04044')},
#  {'FECHA': '2020-05-04',
#   'CASOS_TOTALES': 2510,
#   'AFLUENCIA TOTAL': 1922766.0,
#   '_id': ObjectId('5efacbee0479130f19c04045')},
#  {'FECHA': '2020-05-05',
#   'CASOS_TOTALES': 2189,
#   'AFLUENCIA TOTAL': 1801106.0,
#   '_id': ObjectId('5efacbee0479130f19c04046')},
#  {'FECHA': '2020-05-06',
#   'CASOS_TOTALES': 2380,
#   'AFLUENCIA TOTAL': 1802090.0,
#   '_id': ObjectId('5efacbee0479130f19c04047')},
#  {'FECHA': '2020-05-07',
#   'CASOS_TOTALES': 2457,
#   'AFLUENCIA TOTAL': 1766449.0,
#   '_id': ObjectId('5efacbee0479130f19c04048')},
#  {'FECHA': '2020-05-08',
#   'CASOS_TOTALES': 2509,
#   'AFLUENCIA TOTAL': 1849152.0,
#   '_id': ObjectId('5efacbee0479130f19c04049')},
#  {'FECHA': '2020-05-09',
#   'CASOS_TOTALES': 1587,
#   'AFLUENCIA TOTAL': 1393560.0,
#   '_id': ObjectId('5efacbee0479130f19c0404a')},
#  {'FECHA': '2020-05-10',
#   'CASOS_TOTALES': 1423,
#   'AFLUENCIA TOTAL': 869373.0,
#   '_id': ObjectId('5efacbee0479130f19c0404b')},
#  {'FECHA': '2020-05-11',
#   'CASOS_TOTALES': 3058,
#   'AFLUENCIA TOTAL': 1804818.0,
#   '_id': ObjectId('5efacbee0479130f19c0404c')},
#  {'FECHA': '2020-05-12',
#   'CASOS_TOTALES': 3021,
#   'AFLUENCIA TOTAL': 1764243.0,
#   '_id': ObjectId('5efacbee0479130f19c0404d')},
#  {'FECHA': '2020-05-13',
#   'CASOS_TOTALES': 3223,
#   'AFLUENCIA TOTAL': 1797331.0,
#   '_id': ObjectId('5efacbee0479130f19c0404e')},
#  {'FECHA': '2020-05-14',
#   'CASOS_TOTALES': 3171,
#   'AFLUENCIA TOTAL': 1802946.0,
#   '_id': ObjectId('5efacbee0479130f19c0404f')},
#  {'FECHA': '2020-05-15',
#   'CASOS_TOTALES': 3624,
#   'AFLUENCIA TOTAL': 1967993.0,
#   '_id': ObjectId('5efacbee0479130f19c04050')},
#  {'FECHA': '2020-05-16',
#   'CASOS_TOTALES': 2224,
#   'AFLUENCIA TOTAL': 1529632.0,
#   '_id': ObjectId('5efacbee0479130f19c04051')},
#  {'FECHA': '2020-05-17',
#   'CASOS_TOTALES': 1680,
#   'AFLUENCIA TOTAL': 972733.0,
#   '_id': ObjectId('5efacbee0479130f19c04052')},
#  {'FECHA': '2020-05-18',
#   'CASOS_TOTALES': 4217,
#   'AFLUENCIA TOTAL': 1884360.0,
#   '_id': ObjectId('5efacbee0479130f19c04053')},
#  {'FECHA': '2020-05-19',
#   'CASOS_TOTALES': 3757,
#   'AFLUENCIA TOTAL': 1884195.0,
#   '_id': ObjectId('5efacbee0479130f19c04054')},
#  {'FECHA': '2020-05-20',
#   'CASOS_TOTALES': 4038,
#   'AFLUENCIA TOTAL': 1897704.0,
#   '_id': ObjectId('5efacbee0479130f19c04055')},
#  {'FECHA': '2020-05-21',
#   'CASOS_TOTALES': 4100,
#   'AFLUENCIA TOTAL': 1872828.0,
#   '_id': ObjectId('5efacbee0479130f19c04056')},
#  {'FECHA': '2020-05-22',
#   'CASOS_TOTALES': 4219,
#   'AFLUENCIA TOTAL': 1940203.0,
#   '_id': ObjectId('5efacbee0479130f19c04057')},
#  {'FECHA': '2020-05-23',
#   'CASOS_TOTALES': 2354,
#   'AFLUENCIA TOTAL': 1545160.0,
#   '_id': ObjectId('5efacbee0479130f19c04058')},
#  {'FECHA': '2020-05-24',
#   'CASOS_TOTALES': 1957,
#   'AFLUENCIA TOTAL': 963614.0,
#   '_id': ObjectId('5efacbee0479130f19c04059')},
#  {'FECHA': '2020-05-25',
#   'CASOS_TOTALES': 4809,
#   'AFLUENCIA TOTAL': 1945411.0,
#   '_id': ObjectId('5efacbee0479130f19c0405a')},
#  {'FECHA': '2020-05-26',
#   'CASOS_TOTALES': 4533,
#   'AFLUENCIA TOTAL': 1903118.0,
#   '_id': ObjectId('5efacbee0479130f19c0405b')},
#  {'FECHA': '2020-05-27',
#   'CASOS_TOTALES': 4662,
#   'AFLUENCIA TOTAL': 1925169.0,
#   '_id': ObjectId('5efacbee0479130f19c0405c')},
#  {'FECHA': '2020-05-28',
#   'CASOS_TOTALES': 4440,
#   'AFLUENCIA TOTAL': 1923004.0,
#   '_id': ObjectId('5efacbee0479130f19c0405d')},
#  {'FECHA': '2020-05-29',
#   'CASOS_TOTALES': 4581,
#   'AFLUENCIA TOTAL': 2054956.0,
#   '_id': ObjectId('5efacbee0479130f19c0405e')},
#  {'FECHA': '2020-05-30',
#   'CASOS_TOTALES': 2894,
#   'AFLUENCIA TOTAL': 1633705.0,
#   '_id': ObjectId('5efacbee0479130f19c0405f')},
#  {'FECHA': '2020-05-31',
#   'CASOS_TOTALES': 2161,
#   'AFLUENCIA TOTAL': 1030248.0,
#   '_id': ObjectId('5efacbee0479130f19c04060')},
#  {'FECHA': '2020-06-01',
#   'CASOS_TOTALES': 5586,
#   'AFLUENCIA TOTAL': 2147960.0,
#   '_id': ObjectId('5efacbee0479130f19c04061')},
#  {'FECHA': '2020-06-02',
#   'CASOS_TOTALES': 5083,
#   'AFLUENCIA TOTAL': 2078795.0,
#   '_id': ObjectId('5efacbee0479130f19c04062')},
#  {'FECHA': '2020-06-03',
#   'CASOS_TOTALES': 5266,
#   'AFLUENCIA TOTAL': 2139958.0,
#   '_id': ObjectId('5efacbee0479130f19c04063')},
#  {'FECHA': '2020-06-04',
#   'CASOS_TOTALES': 5198,
#   'AFLUENCIA TOTAL': 2108338.0,
#   '_id': ObjectId('5efacbee0479130f19c04064')},
#  {'FECHA': '2020-06-05',
#   'CASOS_TOTALES': 5399,
#   'AFLUENCIA TOTAL': 2198438.0,
#   '_id': ObjectId('5efacbee0479130f19c04065')},
#  {'FECHA': '2020-06-06',
#   'CASOS_TOTALES': 3100,
#   'AFLUENCIA TOTAL': 1728063.0,
#   '_id': ObjectId('5efacbee0479130f19c04066')},
#  {'FECHA': '2020-06-07',
#   'CASOS_TOTALES': 2474,
#   'AFLUENCIA TOTAL': 1070642.0,
#   '_id': ObjectId('5efacbee0479130f19c04067')},
#  {'FECHA': '2020-06-08',
#   'CASOS_TOTALES': 6519,
#   'AFLUENCIA TOTAL': 2166112.0,
#   '_id': ObjectId('5efacbee0479130f19c04068')},
#  {'FECHA': '2020-06-09',
#   'CASOS_TOTALES': 6125,
#   'AFLUENCIA TOTAL': 2160118.0,
#   '_id': ObjectId('5efacbee0479130f19c04069')},
#  {'FECHA': '2020-06-10',
#   'CASOS_TOTALES': 6176,
#   'AFLUENCIA TOTAL': 2187060.0,
#   '_id': ObjectId('5efacbee0479130f19c0406a')},
#  {'FECHA': '2020-06-11',
#   'CASOS_TOTALES': 5896,
#   'AFLUENCIA TOTAL': 2174493.0,
#   '_id': ObjectId('5efacbee0479130f19c0406b')},
#  {'FECHA': '2020-06-12',
#   'CASOS_TOTALES': 6215,
#   'AFLUENCIA TOTAL': 2309292.0,
#   '_id': ObjectId('5efacbee0479130f19c0406c')},
#  {'FECHA': '2020-06-13',
#   'CASOS_TOTALES': 3295,
#   'AFLUENCIA TOTAL': 1805661.0,
#   '_id': ObjectId('5efacbee0479130f19c0406d')},
#  {'FECHA': '2020-06-14',
#   'CASOS_TOTALES': 2754,
#   'AFLUENCIA TOTAL': 1136913.0,
#   '_id': ObjectId('5efacbee0479130f19c0406e')},
#  {'FECHA': '2020-06-15',
#   'CASOS_TOTALES': 7111,
#   'AFLUENCIA TOTAL': 2370129.0,
#   '_id': ObjectId('5efacbee0479130f19c0406f')},
#  {'FECHA': '2020-06-16',
#   'CASOS_TOTALES': 7074,
#   'AFLUENCIA TOTAL': 2368969.0,
#   '_id': ObjectId('5efacbee0479130f19c04070')},
#  {'FECHA': '2020-06-17',
#   'CASOS_TOTALES': 6877,
#   'AFLUENCIA TOTAL': 2365107.0,
#   '_id': ObjectId('5efacbee0479130f19c04071')},
#  {'FECHA': '2020-06-18',
#   'CASOS_TOTALES': 7322,
#   'AFLUENCIA TOTAL': 2379891.0,
#   '_id': ObjectId('5efacbee0479130f19c04072')},
#  {'FECHA': '2020-06-19',
#   'CASOS_TOTALES': 7577,
#   'AFLUENCIA TOTAL': 2429433.0,
#   '_id': ObjectId('5efacbee0479130f19c04073')},
#  {'FECHA': '2020-06-20',
#   'CASOS_TOTALES': 4245,
#   'AFLUENCIA TOTAL': 1938173.0,
#   '_id': ObjectId('5efacbee0479130f19c04074')},
#  {'FECHA': '2020-06-21',
#   'CASOS_TOTALES': 3121,
#   'AFLUENCIA TOTAL': 1191119.0,
#   '_id': ObjectId('5efacbee0479130f19c04075')},
#  {'FECHA': '2020-06-22',
#   'CASOS_TOTALES': 10267,
#   'AFLUENCIA TOTAL': 2275450.0,
#   '_id': ObjectId('5efacbee0479130f19c04076')},
#  {'FECHA': '2020-06-23',
#   'CASOS_TOTALES': 10909,
#   'AFLUENCIA TOTAL': 2309407.0,
#   '_id': ObjectId('5efacbee0479130f19c04077')},
#  {'FECHA': '2020-06-24',
#   'CASOS_TOTALES': 4760,
#   'AFLUENCIA TOTAL': 2404465.0,
#   '_id': ObjectId('5efacbee0479130f19c04078')}]
